# %%
# !pip install faiss-cpu pandas torch sentence-transformers transformers numpy matplotlib seaborn spacy
# !python -m spacy download en_core_web_md
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 17.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 35.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 26.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 18.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, faiss-cpu, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed faiss-cpu-1.11.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Collecting en-core-web-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.8.0/en_core_web_md-3.8.0-py3-none-any.whl (33.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 20.3 MB/s eta 0:00:00
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# A primeira célula carrega e prepara os dados e cria um sistema de busca vetorial inteligente
#(pronto para expandir consultas e responder de forma mais precisa depois).

import spacy
import faiss
import pandas as pd
import numpy as np
import torch
from sentence_transformers import SentenceTransformer
from transformers import T5Tokenizer, T5ForConditionalGeneration
import nltk
from nltk.corpus import wordnet
from datetime import datetime

# Baixar os dados necessários para WordNet
nltk.download("wordnet")

# Carregar modelos
spacy.prefer_gpu()
nlp = spacy.load("en_core_web_sm")
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")
t5_model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")

# Carregar dataset
df = pd.read_csv("amazon_with_sales.csv")

# Definir feriados e datas especiais
data_especial = {
    'New ano': '01-01',
    'Valentines dia': '06-12',
    'Mothers dia': '05-12',
    'Black Fridia': '11-24',
    'Christmas': '12-25'
}

# Função para enriquecer dados de data
def novo_data_info(data_str):
    data = datetime.strptime(data_str, "%Y-%m-%d")
    mes = data.month
    dia = data.day
    ano = data.year

    # Estações do ano (hemisfério norte)
    if mes in [12, 1, 2]:
        estacao = 'Winter'
    elif mes in [3, 4, 5]:
        estacao = 'Spring'
    elif mes in [6, 7, 8]:
        estacao = 'Summer'
    else:
        estacao = 'Autumn'

    # Verificar se a data coincide com datas especiais
    periodo_especial = 'None'
    for evento, evento_data in data_especial.items():
        evento_mes, evento_dia = map(int, evento_data.split('-'))
        if mes == evento_mes and dia == evento_dia:
            periodo_especial = evento

    return {
        'ano': ano,
        'mes': mes,
        'dia': dia,
        'estacao': estacao,
        'periodo_especial': periodo_especial
    }

# Aplicar enriquecimento de data
data_info = df['date'].apply(novo_data_info).apply(pd.Series)
df = pd.concat([df, data_info], axis=1)

# Criar dicionário de sinônimos para categorias
categorias = set(df["category"].dropna().str.lower().str.strip().unique())
categorias_sinonimos = {}
for category in categorias:
    terms = category.split("|")
    synonyms_set = set(terms)
    for term in terms:
        doc = nlp(term.replace("&", " "))
        for token in doc:
            for synset in wordnet.synsets(token.text):
                for lemma in synset.lemmas():
                    synonyms_set.add(lemma.name().replace("_", " "))
    categorias_sinonimos[category] = list(synonyms_set)

# Adicionar sinônimos ao texto do produto antes de gerar os embeddings
def expandir_descricao_do_produto(row):
    category = row["category"].lower().strip()
    synonyms = categorias_sinonimos.get(category, [])
    expanded_text = row["product_name"] + " " + row["about_product"] + " " + " ".join(categorias_sinonimos.get(category, []))
    return embedding_model.encode(expanded_text, normalize_embeddings=True)

# Criar embeddings vetoriais incluindo sinônimos
df["embedding"] = df.apply(expandir_descricao_do_produto, axis=1)

# Criar índice FAISS
dimension = df["embedding"].iloc[0].shape[0]
quantizer = faiss.IndexFlatL2(dimension)  # base para clusters
nlist = 100  # número de clusters (pode ajustar para datasets maiores ou menores)

index = faiss.IndexIVFFlat(quantizer, dimension, nlist, faiss.METRIC_L2)
embeddings_matrix = np.vstack(df["embedding"].values).astype("float32")
# Treinar o índice antes de adicionar (obrigatório para IVFFlat)
index.train(embeddings_matrix)
index.add(embeddings_matrix)

# Função de extração de categorias
def extrair_categorias(query):
    doc = nlp(query.lower())
    categorias = []
    categoria_atual = []

    stopwords = {"difference", "comparison", "know", "want", "between", "and", "or", "vs", "to", "the", "which", "what"}

    for token in doc:
        if token.pos_ in ["NOUN", "PROPN"] and token.text not in stopwords:
            categoria_atual.append(token.text)
        elif token.pos_ == "ADJ":
            categoria_atual.append(token.text)
        else:
            if categoria_atual:
                categorias.append(" ".join(categoria_atual))
                categoria_atual = []
    if categoria_atual:
        categorias.append(" ".join(categoria_atual))

    if len(categorias) > 2:
        categorias = categorias[-2:]

    return categorias
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# transforma o que o usuário digita em uma ação inteligente e focada: comparar categorias ou analisar produtos por período.
import spacy
import faiss
import pandas as pd
import numpy as np
import torch
from sentence_transformers import SentenceTransformer
from transformers import T5Tokenizer, T5ForConditionalGeneration
import nltk
from nltk.corpus import wordnet
from sklearn.preprocessing import MinMaxScaler

# Carregar o modelo spaCy
nlp = spacy.load("en_core_web_sm")

def  detecta_query_tipo(query):
    periodos = extrair_periodos(query)
    categorias = extrair_categorias(query)

    if periodos and categorias:
        return "period_analysis"  # Produto + Período
    elif len(categorias) >= 2:
        return "category_comparison"  # Duas categorias
    else:
        return "unknown"

# Função para extrair categorias usando o dicionário
def extrair_categorias(query):
    doc = nlp(query.lower())
    extracted = []
    stopwords = {"difference", "comparison", "know", "want", "between", "and", "or", "vs", "to", "the", "which", "what"}

    # Detecta frases nominais como "home entertainment"
    frases_sinon = [chunk.text.strip().lower() for chunk in doc.noun_chunks]

    for frase in frases_sinon:
        frase = frase.strip()
        if frase in categorias:
            extracted.append(frase)
        else:
            for syn_list in categorias_sinonimos.values():
                if frase in syn_list:
                    extracted.append(frase)

    return list(set(extracted))

# Função para extrair períodos
def extrair_periodos(query):
    periodos_conhecidos = {
        "summer", "winter", "spring", "autumn",
        "january", "february", "march", "april", "may", "june",
        "july", "august", "september", "october", "november", "december",
        "new ano", "valentines dia", "mothers dia", "black fridia", "christmas"
    }

    query = query.lower()
    doc = nlp(query)
    frases = [chunk.text.lower() for chunk in doc.noun_chunks]
    tokens = [token.text.lower() for token in doc]

    detected = []

    for frase in frases + tokens:
        if frase in periodos_conhecidos and frase not in detected:
            detected.append(frase)

    # Verificação manual para datas compostas (caso o spaCy falhe)
    for period in periodos_conhecidos:
        if " " in period and period in query and period not in detected:
            detected.append(period)

    return detected

def expandir_query_com_sinonimos(query, categorias_sinonimos, context_words=None):
    words = query.lower().split()
    expanded_words = []

    for word in words:
        expanded_words.append(word)
        for category, synonyms in categorias_sinonimos.items():
            if word in synonyms or word == category:
                expanded_words.extend(synonyms)

    if context_words:
        expanded_words.extend(context_words)

    return " ".join(list(set(expanded_words)))

# Buscar produtos no índice FAISS
def query_index(query_text, max_resultados=50, distance_threshold=2, query_tipo="category_comparison"):
    # Definir palavras de contexto
    if query_tipo == "period_analysis":
        context_words = ["sale", "sold", "discount", "estacao", "best seller"]
    else:
        context_words = ["compare", "difference", "specs", "features"]

    expanded_query = expandir_query_com_sinonimos(query_text, categorias_sinonimos, context_words)

    query_embedding = embedding_model.encode([expanded_query], normalize_embeddings=True)
    distances, indices = index.search(query_embedding, max_resultados)

    resultados = df.iloc[indices[0]].copy()
    resultados["distance"] = distances[0]
    resultados_filtrados = resultados[resultados["distance"] <= distance_threshold]

    if resultados_filtrados.empty:
        print("Nenhum produto encontrado com distância baixa, retornando os melhores disponíveis.")
        resultados_filtrados = resultados.head(10)

    if not resultados_filtrados.empty:
        resultados_filtrados = resultados_filtrados.sort_values(by="sales_quantity", ascending=False)

    return resultados_filtrados.reset_index(drop=True)

# Buscar produtos por período
def query_index_by_period(query_text, period_mess, max_resultados=50, distance_threshold=2):
    df['data'] = pd.to_datatime(df['data'], errors='coerce')
    df['mes'] = df['data'].dt.mes
    period_df = df[df['mes'].isin(period_mess)]

    if period_df.empty:
        print(f"Nenhum dado encontrado para o período {period_mess}.")
        return pd.DataFrame()

    # Expandir a consulta para venda
    expanded_query = expandir_query_com_sinonimos(query_text, categorias_sinonimos, context_words=["sale", "sold", "discount", "estacao", "best seller"])

    query_embedding = embedding_model.encode([expanded_query], normalize_embeddings=True)
    distances, indices = index.search(query_embedding, max_resultados)

    valid_indices = [i for i in indices[0] if i < len(period_df)]

    if not valid_indices:
        print(f"Nenhum resultado FAISS válido para o período {period_mess}.")
        return pd.DataFrame()

    resultados = period_df.iloc[valid_indices].copy()
    resultados["distance"] = distances[0][:len(valid_indices)]

    resultados_filtrados = resultados[resultados["distance"] <= distance_threshold]

    if resultados_filtrados.empty:
        print("Nenhum produto encontrado com distância baixa no período, retornando os melhores disponíveis.")
        resultados_filtrados = resultados.head(10)

    if not resultados_filtrados.empty:
        resultados_filtrados = resultados_filtrados.sort_values(by="sales_quantity", ascending=False)

    return resultados_filtrados.reset_index(drop=True)

# Gerar resposta por categoria
def generate_response(query):
    categorias = extrair_categorias(query)
    if isinstance(categorias, str):
        return categorias

    response_list = {}

    for category in categorias:
        print(f"Buscando produtos relacionados a: {category}")
        resultados = query_index(category, max_resultados=50)

        response_list[category.capitalize()] = []

        for _, row in resultados.iterrows():
            response_list[category.capitalize()].append({
                "product_id": row["product_id"],
                "product_name": row["product_name"],
                "product_link": row["product_link"]
            })

        if not response_list[category.capitalize()]:
            response_list[category.capitalize()].append({
                "product_id": None,
                "product_name": f"Nenhum produto encontrado relacionado a '{category.capitalize()}'.",
                "product_link": None
            })

    print("\n--- Resultados por Categoria ---")
    for category, products in response_list.items():
        print(f"\nCategoria: {category}")
        for product in products:
            if isinstance(product, dict):
                print(f"- {product['product_name']} (ID: {product['product_id']}) - {product['product_link']}")
            else:
                print(product)

    return response_list

# Dados estruturados que serão usados no gráfico e no texto via RAG
total_sales = 0;
category_total_sales = {}  # Ex: {"Phone": 1200}

# Gerar resposta considerando períodos
def generate_period_response(query):
    periodos = {
        "summer": [6, 7, 8],
        "winter": [12, 1, 2],
        "spring": [3, 4, 5],
        "autumn": [9, 10, 11],
        "january": [1],
        "february": [2],
        "march": [3],
        "april": [4],
        "may": [5],
        "june": [6],
        "july": [7],
        "august": [8],
        "september": [9],
        "october": [10],
        "november": [11],
        "december": [12]
    }

    # Datas especiais tratadas como períodos nomeados
    data_especial = {
      "new ano": "01-01",
      "valentines dia": "06-12",
      "mothers dia": "05-12",
      "black fridia": "11-24",
      "christmas": "12-25"
       }

    detected_periodos = extrair_periodos(query)
    print(f"Periodos detectados: {detected_periodos}")

    categorias = extrair_categorias(query)
    print(f"Categorias detectadas: {categorias}")

    if not detected_periodos:
        print("Nenhum período detectado na consulta.")
        return {}
    if not categorias:
        print("Nenhuma categoria detectada na consulta.")
        return {}

    response_list = {}

    global category_total_sales
    global total_sales

    for category in categorias:
        print(f"\nBuscando produtos para a categoria: {category.capitalize()}")
        category_resultados = query_index(category, max_resultados=50)

        if category_resultados.empty:
            # Corrigir aqui: colocar dict vazio, mas formato correto
            response_list[category.capitalize()] = {"Geral": [{
                "product_id": None,
                "product_name": f"Nenhum produto encontrado para a categoria '{category.capitalize()}'.",
                "product_link": None
            }]}
        else:
            category_resultados['date'] = pd.to_datetime(category_resultados['date'], errors='coerce')
            category_resultados['mes'] = category_resultados['date'].dt.month
            print(f"Meses extraídos: {category_resultados['mes'].unique()}")
            category_resultados['sales_quantity'] = pd.to_numeric(category_resultados['sales_quantity'], errors='coerce')
            total_sales = category_resultados['sales_quantity'].sum()
            category_total_sales[category.capitalize()] = total_sales


            filtered_by_periodos = {}
            #######
            for period in detected_periodos:
                print(f"\nFiltrando produtos para o período: {period.capitalize()}")

                if period in data_especial:
                    # Tratar como uma data exata
                    mes_str, dia_str = data_especial[period].split("-")
                    evento_mes = int(mes_str)
                    evento_dia = int(dia_str)

                    category_resultados["dia"] = category_resultados["data"].dt.dia
                    category_resultados["mes"] = category_resultados["data"].dt.mes
                    # +/- 2 dias de diferença da data
                    period_resultados = category_resultados[
                        (category_resultados["mes"] == evento_mes) &
                        (abs(category_resultados["dia"] - evento_dia) <= 2)
                    ]
                elif period in periodos:
                    print(f"Meses disponíveis para filtro: {periodos[period]}")
                    period_resultados = category_resultados[category_resultados["mes"].isin(periodos[period])]
                else:
                    print(f"Período não reconhecido: {period}")
                    continue

                print(f"Filtrados: {period_resultados.shape[0]} produtos para o período {period.capitalize()}")

                if period_resultados.empty:
                    filtered_by_periodos[period.capitalize()] = [{
                        "product_id": None,
                        "product_name": f"Nenhum produto de '{category.capitalize()}' encontrado para o período '{period.capitalize()}'.",
                        "product_link": None
                    }]
                else:
                    filtered_by_periodos[period.capitalize()] = []
                    for _, row in period_resultados.iterrows():
                        filtered_by_periodos[period.capitalize()].append({
                            "product_id": row["product_id"],
                            "product_name": row["product_name"],
                            "product_link": row["product_link"]
                        })

            if filtered_by_periodos:
                response_list[category.capitalize()] = filtered_by_periodos

    print("\n--- Resultados por Período ---")
    for category, period_resultados in response_list.items():
        print(f"\nCategoria: {category}")
        for period, products in period_resultados.items():
            print(f"\nPeríodo: {period}")
            for product in products:
                if isinstance(product, dict):
                    print(f"- {product['product_id']} - {product['product_name']} - {product['product_link']}")
                else:
                    print(product)

    return response_list

# phone sold in spring and winter
# tv camera sold in spring and winter
# difference in sales between phone and tv
query = "difference in sales between phone and tv"

query_tipo =  detecta_query_tipo(query)

if query_tipo == "period_analysis":
    print("\n Detectado: Análise de Vendas por Período")
    period_resultados = generate_period_response(query)

elif query_tipo == "category_comparison":
    print("\n Detectado: Comparação de Categorias")
    resultados = generate_response(query)
else:

    print("\n Não foi possível identificar o tipo de consulta.")
print(total_sales)
# Out:
#  Detectado: Comparação de Categorias
# Buscando produtos relacionados a: phone
# Buscando produtos relacionados a: tv
#
# --- Resultados por Categoria ---
#
# Categoria: Phone
# - JBL C100SI Wired In Ear Headphones with Mic, JBL Pure Bass Sound, One Button Multi-function Remote, Premium Metallic Finish, Angled Buds for Comfort fit (Red) (ID: B01DF26V7A) - https://www.amazon.in/JBL-C100SI-Ear-Headphones-Mic/dp/B01DF26V7A/ref=sr_1_159?qid=1672895791&s=electronics&sr=1-159
# - boAt Airdopes 121v2 in-Ear True Wireless Earbuds with Upto 14 Hours Playback, 8MM Drivers, Battery Indicators, Lightweight Earbuds & Multifunction Controls (Active Black, with Mic) (ID: B08JQN8DGZ) - https://www.amazon.in/Airdopes-121v2-Bluetooth-Immersive-Assistant/dp/B08JQN8DGZ/ref=sr_1_8?qid=1672902995&s=computers&sr=1-8
# - JBL C100SI Wired In Ear Headphones with Mic, JBL Pure Bass Sound, One Button Multi-function Remote, Angled Buds for Comfort fit (Black) (ID: B01DEWVZ2C) - https://www.amazon.in/JBL-C100SI-Ear-Headphones-Black/dp/B01DEWVZ2C/ref=sr_1_15?qid=1672902995&s=computers&sr=1-15
# - boAt Rockerz 400 Bluetooth On Ear Headphones With Mic With Upto 8 Hours Playback & Soft Padded Ear Cushions(Grey/Green) (ID: B01FSYQ2A4) - https://www.amazon.in/Super-Rockerz-400-Bluetooth-Headphones/dp/B01FSYQ2A4/ref=sr_1_307?qid=1672895835&s=electronics&sr=1-307
# - JBL C100SI Wired In Ear Headphones with Mic, JBL Pure Bass Sound, One Button Multi-function Remote, Angled Buds for Comfort fit (Black) (ID: B01DEWVZ2C) - https://www.amazon.in/JBL-C100SI-Ear-Headphones-Black/dp/B01DEWVZ2C/ref=sr_1_16?qid=1672895748&s=electronics&sr=1-16
# - JBL C50HI, Wired in Ear Headphones with Mic, One Button Multi-Function Remote, Lightweight & Comfortable fit (Black) (ID: B07JQKQ91F) - https://www.amazon.in/JBL-C50HI-Ear-Headphones-Black/dp/B07JQKQ91F/ref=sr_1_18?qid=1672902995&s=computers&sr=1-18
# - boAt Rockerz 400 Bluetooth On Ear Headphones With Mic With Upto 8 Hours Playback & Soft Padded Ear Cushions(Grey/Green) (ID: B01FSYQ2A4) - https://www.amazon.in/Super-Rockerz-400-Bluetooth-Headphones/dp/B01FSYQ2A4/ref=sr_1_373?qid=1672903013&s=computers&sr=1-373
# - JBL C200SI, Premium in Ear Wired Earphones with Mic, Signature Sound, One Button Multi-Function Remote, Angled Earbuds for Comfort fit (Blue) (ID: B07DFYJRQV) - https://www.amazon.in/JBL-C200SI-Ear-Headphones-Mystic/dp/B07DFYJRQV/ref=sr_1_134?qid=1672903001&s=computers&sr=1-134
# - boAt Rockerz 450 Bluetooth On Ear Headphones with Mic, Upto 15 Hours Playback, 40MM Drivers, Padded Ear Cushions, Integrated Controls and Dual Modes(Luscious Black) (ID: B07PR1CL3S) - https://www.amazon.in/Rockerz-450-Wireless-Bluetooth-Headphone/dp/B07PR1CL3S/ref=sr_1_16?qid=1672902995&s=computers&sr=1-16
# - Fire-Boltt India's No 1 Smartwatch Brand Ring Bluetooth Calling with SpO2 & 1.7” Metal Body with Blood Oxygen Monitoring, Continuous Heart Rate, Full Touch & Multiple Watch Faces (ID: B0972BQ2RS) - https://www.amazon.in/Fire-Boltt-Smartwatch-Monitoring-Continuous-BSW005/dp/B0972BQ2RS/ref=sr_1_180?qid=1672903004&s=computers&sr=1-180
# - PTron Tangentbeat in-Ear Bluetooth 5.0 Wireless Headphones with Mic, Enhanced Bass, 10mm Drivers, Clear Calls, Snug-Fit, Fast Charging, Magnetic Buds, Voice Assistant & IPX4 Wireless Neckband (Black) (ID: B08D77XZX5) - https://www.amazon.in/Tangentbeat-Bluetooth-Headphones-Waterproof-Cancelation/dp/B08D77XZX5/ref=sr_1_18?qid=1672895748&s=electronics&sr=1-18
# - boAt Rockerz 370 On Ear Bluetooth Headphones with Upto 12 Hours Playtime, Cozy Padded Earcups and Bluetooth v5.0, with Mic (Buoyant Black) (ID: B0856HNMR7) - https://www.amazon.in/Rockerz-370-Headphone-Bluetooth-Lightweight/dp/B0856HNMR7/ref=sr_1_92?qid=1672902998&s=computers&sr=1-92
# - Boult Audio Truebuds with 30H Playtime, IPX7 Waterproof, Lightning Boult™ Type C Fast Charging (10 Min=100Mins), BoomX™ Tech Rich Bass, Pro+ Calling HD Mic, Touch Controls in Ear Earbuds TWS (Grey) (ID: B08CFCK6CW) - https://www.amazon.in/Boult-Audio-TrueBuds-Wireless-Waterproof/dp/B08CFCK6CW/ref=sr_1_215?qid=1672903005&s=computers&sr=1-215
# - realme Buds Wireless in Ear Bluetooth Earphones with mic, 11.2mm Bass Boost Driver, Magnetic Fast Pair, Fast Charging and 12 Hrs Playtime (Yellow) (ID: B07XJWTYM2) - https://www.amazon.in/realme-RMA108-Realme-Buds-Wireless/dp/B07XJWTYM2/ref=sr_1_387?qid=1672903014&s=computers&sr=1-387
# - PTron Tangent Lite Bluetooth 5.0 Earphones with Mic, Hi-Fi Stereo Sound Neckband, 8Hrs Playtime, Lightweight Snug-fit in-Ear Headphones, IPX4 Water Resistant, Fast Charge & Voice Assistant (Black) (ID: B085W8CFLH) - https://www.amazon.in/Tangent-Lite-Magnetic-Bluetooth-Headphones/dp/B085W8CFLH/ref=sr_1_84?qid=1672895770&s=electronics&sr=1-84
# - boAt Airdopes 171 in Ear Bluetooth True Wireless Earbuds with Upto 13 Hours Battery, IPX4, Bluetooth v5.0, Dual Tone Finish with Mic (Mysterious Blue) (ID: B086WMSCN3) - https://www.amazon.in/Boat-Airdopes-171-Functionality-Resistance/dp/B086WMSCN3/ref=sr_1_147?qid=1672903002&s=computers&sr=1-147
# - Boult Audio AirBass PowerBuds with Inbuilt Powerbank, 120H Total Playtime, IPX7 Fully Waterproof, Lightning Boult Type-C Fast Charging, Low Latency Gaming, TWS Earbuds with Pro+ Calling Mic (Black) (ID: B08D11DZ2W) - https://www.amazon.in/Boult-Audio-PowerBuds-Wireless-Waterproof/dp/B08D11DZ2W/ref=sr_1_69?qid=1672902997&s=computers&sr=1-69
# - Boult Audio ZCharge Bluetooth Wireless in Ear Earphones with Mic, 40H Playtime and Super Fast Charging, Environmental Noise Cancellation for Pro+ Calling and IPX5 Water Resistant (Black) (ID: B09NR6G588) - https://www.amazon.in/Boult-Audio-Bluetooth-Environmental-Cancellation/dp/B09NR6G588/ref=sr_1_67?qid=1672902997&s=computers&sr=1-67
# - AirCase Rugged Hard Drive Case for 2.5-inch Western Digital, Seagate, Toshiba, Portable Storage Shell for Gadget Hard Disk USB Cable Power Bank Mobile Charger Earphone, Waterproof (Black) (ID: B00NNQMYNE) - https://www.amazon.in/AirCase-External-Drive-2-5-Inch-Black/dp/B00NNQMYNE/ref=sr_1_155?qid=1672903002&s=computers&sr=1-155
# - Noise Buds Vs104 Bluetooth Truly Wireless in Ear Earbuds with Mic, 30-Hours of Playtime, Instacharge, 13Mm Driver and Hyper Sync (Charcoal Black) (ID: B09Y5MP7C4) - https://www.amazon.in/Noise-Bluetooth-Wireless-30-Hours-Instacharge/dp/B09Y5MP7C4/ref=sr_1_132?qid=1672903001&s=computers&sr=1-132
# - Noise Buds VS201 V2 in-Ear Truly Wireless Earbuds with Dual Equalizer | with Mic | Total 14-Hour Playtime | Full Touch Control | IPX5 Water Resistance and Bluetooth v5.1 (Olive Green) (ID: B098R25TGC) - https://www.amazon.in/Noise-Wireless-Equalizer-Resistance-Bluetooth/dp/B098R25TGC/ref=sr_1_220?qid=1672903006&s=computers&sr=1-220
# - boAt Rockerz 550 Over Ear Bluetooth Headphones with Upto 20 Hours Playback, 50MM Drivers, Soft Padded Ear Cushions and Physical Noise Isolation, Without Mic (Black) (ID: B0856HY85J) - https://www.amazon.in/Boat-Rockerz-550-Headphone-Aesthetics/dp/B0856HY85J/ref=sr_1_85?qid=1672902998&s=computers&sr=1-85
# - Gizga Essentials Earphone Carrying Case, Multi-Purpose Pocket Storage Travel Organizer for Earphones, Headset, Pen Drives, SD Cards, Shock-Proof Ballistic Nylon, Soft Fabric, Mesh Pocket, Green (ID: B07DKZCZ89) - https://www.amazon.in/Essentials-G11-Earphone-Carrying-Earphones/dp/B07DKZCZ89/ref=sr_1_222?qid=1672903006&s=computers&sr=1-222
# - Boult Audio Airbass Propods X TWS Bluetooth Truly Wireless in Ear Earbuds with Mic, 32H Playtime, Fast Charging Type-C, Ipx5 Water Resistant, Touch Controls and Voice Assistant (Red) (ID: B09ND94ZRG) - https://www.amazon.in/Boult-Audio-Bluetooth-Resistant-Assistant/dp/B09ND94ZRG/ref=sr_1_310?qid=1672903010&s=computers&sr=1-310
# - ZEBRONICS Zeb-Evolve Wireless in Ear Neckband Earphone with Supporting Bluetooth v5.0, Voice Assistant, Rapid Charge, Call Function & Magnetic Earpiece, with mic (Metallic Blue) (ID: B09GFWJDY1) - https://www.amazon.in/ZEBRONICS-Zeb-Evolve-Supporting-Metallic-Blue/dp/B09GFWJDY1/ref=sr_1_250?qid=1672903007&s=computers&sr=1-250
# - Gizga Essentials Hard Drive Case Shell, 6.35cm/2.5-inch, Portable Storage Organizer Bag for Earphone USB Cable Power Bank Mobile Charger Digital Gadget Hard Disk, Water Resistance Material, Black (ID: B0765B3TH7) - https://www.amazon.in/GIZGA-inch-Hard-Drive-Black/dp/B0765B3TH7/ref=sr_1_74?qid=1672902998&s=computers&sr=1-74
# - Tukzer Capacitive Stylus Pen for Touch Screens Devices, Fine Point, Lightweight Metal Body with Magnetism Cover Cap for Smartphones/Tablets/iPad/iPad Pro/iPhone (Grey) (ID: B08K4PSZ3V) - https://www.amazon.in/Tukzer-Capacitive-Lightweight-Magnetism-Smartphones/dp/B08K4PSZ3V/ref=sr_1_161?qid=1672895791&s=electronics&sr=1-161
# - Boult Audio FXCharge with ENC, 32H Playtime, 5min=7H Type C Fast Charging, Zen ENC, 14.2 mm BoomX Rich Bass, IPX5, Bluetooth Wireless in Ear Earphones Neckband with mic (Black) (ID: B0B1F6GQPS) - https://www.amazon.in/Boult-Audio-Environmental-Cancellation-Bluetooth/dp/B0B1F6GQPS/ref=sr_1_75?qid=1672902998&s=computers&sr=1-75
# - Hp Wired On Ear Headphones With Mic With 3.5 Mm Drivers, In-Built Noise Cancelling, Foldable And Adjustable For Laptop/Pc/Office/Home/ 1 Year Warranty (B4B09Pa) (ID: B009LJ2BXA) - https://www.amazon.in/HP-B4B09PA-Headphones-with-Mic/dp/B009LJ2BXA/ref=sr_1_361?qid=1672903013&s=computers&sr=1-361
# - Noise Buds VS402 Truly Wireless in Ear Earbuds, 35-Hours of Playtime, Instacharge, Quad Mic with ENC, Hyper Sync, Low Latency, 10mm Driver, Bluetooth v5.3 and Breathing LED Lights (Neon Black) (ID: B0B217Z5VK) - https://www.amazon.in/Noise-Wireless-Instacharge-Bluetooth-Breathing/dp/B0B217Z5VK/ref=sr_1_157?qid=1672903002&s=computers&sr=1-157
# - Robustrion Smart Trifold Hard Back Flip Stand Case Cover for Apple iPad 10.2 Cover iPad 9th Generation Cover 2021 8th Gen 2020 7th Gen 2019 Generation Case - Black (ID: B07YNHCW6N) - https://www.amazon.in/Robustrion-Smart-Trifold-Stand-Generation/dp/B07YNHCW6N/ref=sr_1_331?qid=1672903011&s=computers&sr=1-331
# - SaleOn™ Portable Storage Organizer Bag for Earphone USB Cable Power Bank Mobile Charger Digital Gadget Hard Disk, Water Resistance Material - Dark Grey (ID: B07NTKGW45) - https://www.amazon.in/SaleOnTM-Portable-Organizer-Earphone-Assorted/dp/B07NTKGW45/ref=sr_1_384?qid=1672903013&s=computers&sr=1-384
# - ZEBRONICS Zeb-Bro in Ear Wired Earphones with Mic, 3.5mm Audio Jack, 10mm Drivers, Phone/Tablet Compatible(Black) (ID: B07T5DKR5D) - https://www.amazon.in/Zebronics-Zeb-Bro-Wired-Earphone/dp/B07T5DKR5D/ref=sr_1_14?qid=1672902995&s=computers&sr=1-14
# - Boult Audio Bass Buds Q2 Lightweight Stereo Wired Over Ear Headphones Set with Mic with Deep Bass, Comfortable Ear Cushions, & Long Cord (Black) (ID: B08FY4FG5X) - https://www.amazon.in/Boult-Audio-Wired-Lightweight-Comfortable/dp/B08FY4FG5X/ref=sr_1_371?qid=1672903013&s=computers&sr=1-371
# - Boult Audio Airbass Z20 True Wireless, 40H Battery Life, Zen ENC Mic, Type-C Lightning Boult Fast Charging (10Mins=100Mins), BoomX Tech Bass, ENC, IPX5 in Ear Earbuds with mic (Green) (ID: B0B31BYXQQ) - https://www.amazon.in/Boult-Audio-Lightning-Environmental-Cancellation/dp/B0B31BYXQQ/ref=sr_1_50?qid=1672902997&s=computers&sr=1-50
# - Wings Phantom Pro Earphones Gaming Earbuds with LED Battery Indicator, 50ms Low Latency, Bluetooth 5.3, 40 Hours Playtime, MEMs Mic, IPX4 Resist, 12mm Driver, 500mah case, Headphones, (Black TWS) (ID: B09MDCZJXS) - https://www.amazon.in/Wings-Phantom-Indicator-Bluetooth-Playtime/dp/B09MDCZJXS/ref=sr_1_389?qid=1672903014&s=computers&sr=1-389
# - boAt Airdopes 181 in-Ear True Wireless Earbuds with ENx  Tech, Beast  Mode(Low Latency Upto 60ms) for Gaming, with Mic, ASAP  Charge, 20H Playtime, Bluetooth v5.2, IPX4 & IWP (Cool Grey) (ID: B09PL79D2X) - https://www.amazon.in/Airdopes-181-Playtime-Bluetooth-Wireless/dp/B09PL79D2X/ref=sr_1_116?qid=1672903000&s=computers&sr=1-116
# - Noise Agile 2 Buzz Bluetooth Calling Smart Watch with 1.28" TFT Display,Dual Button,in-Built Mic & Speaker,AI Voice Assistant, Health Suite,in-Built Games, 100 Watch Faces-(Jet Black) (ID: B0B5GF6DQD) - https://www.amazon.in/Noise-Bluetooth-Calling-Display-Assistant/dp/B0B5GF6DQD/ref=sr_1_238?qid=1672895814&s=electronics&sr=1-238
# - EN LIGNE Adjustable Cell Phone Stand, Foldable Portable Phone Stand Phone Holder for Desk, Desktop Tablet Stand Compatible with Mobile Phone/iPad/Tablet (Black) (ID: B0B3DV7S9B) - https://www.amazon.in/EN-LIGNE-Adjustable-Tabletop-Compatible/dp/B0B3DV7S9B/ref=sr_1_293?qid=1672895835&s=electronics&sr=1-293
# - Wecool Moonwalk M1 ENC True Wireless in Ear Earbuds with Mic, Titanium Drivers for Rich Bass Experience, 40+ Hours Play Time, Type C Fast Charging, Low Latency, BT 5.3, IPX5, Deep Bass (Black) (ID: B0B5GJRTHB) - https://www.amazon.in/Moonwalk-Wireless-Titanium-Experience-Charging/dp/B0B5GJRTHB/ref=sr_1_397?qid=1672903014&s=computers&sr=1-397
# - Sounce Spiral Charger Cable Protector Data Cable Saver Charging Cord Protective Cable Cover Headphone MacBook Laptop Earphone Cell Phone Set of 3 (Cable Protector (12 Units)) (ID: B085HY1DGR) - https://www.amazon.in/Sounce-Charger-Protector-Charging-Protective/dp/B085HY1DGR/ref=sr_1_64?qid=1672902997&s=computers&sr=1-64
# - ZEBRONICS Zeb-Buds 30 3.5Mm Stereo Wired in Ear Earphones with Mic for Calling, Volume Control, Multifunction Button, 14Mm Drivers, Stylish Eartip,1.2 Meter Durable Cable and Lightweight Design(Red) (ID: B09SGGRKV8) - https://www.amazon.in/Zebronics-Zeb-Buds-30-Multifunction-Lightweight/dp/B09SGGRKV8/ref=sr_1_278?qid=1672903008&s=computers&sr=1-278
# - Sounce 360 Adjustable Mobile Phone Holder, Universal Phone Holder Clip Lazy Bracket Flexible Gooseneck Clamp Long Arms Mount for Mobile Tabletop Stand for Bedroom, Office, Bathroom, White (ID: B096TWZRJC) - https://www.amazon.in/Sounce-Adjustable-Universal-Flexible-Gooseneck/dp/B096TWZRJC/ref=sr_1_269?qid=1672895828&s=electronics&sr=1-269
# - Wayona Nylon Braided USB Data Sync and Fast Charging 3A Short Power Bank Cable For iPhones, iPad Air, iPad mini, iPod Nano and iPod Touch (Grey) (ID: B07JNVF678) - https://www.amazon.in/Wayona-Nylon-Braided-Charging-iPhones/dp/B07JNVF678/ref=sr_1_117?qid=1672909129&s=electronics&sr=1-117
# - Silicone Rubber Earbuds Tips, Eartips, Earpads, Earplugs, for Replacement in Earphones and Bluetooth Medium Size (10 Pcs Black) (ID: B08X77LM8C) - https://www.amazon.in/Silicone-Earplugs-Replacement-Earphones-Bluetooth/dp/B08X77LM8C/ref=sr_1_376?qid=1672903013&s=computers&sr=1-376
# - Sounce Spiral Charger Cable Protector Data Cable Saver Charging Cord Protective Cable Cover Headphone MacBook Laptop Earphone Cell Phone Set of 3 (Cable Protector (12 Units)) (ID: B085HY1DGR) - https://www.amazon.in/Sounce-Charger-Protector-Charging-Protective/dp/B085HY1DGR/ref=sr_1_76?qid=1672895770&s=electronics&sr=1-76
# - Boult Audio Omega with 30dB ANC+ ENC, 32H Playtime, 45ms Latency Gaming Mode, Quad Mic Zen ENC, 3 Equalizer Modes, ANC, Type-C Fast Charging, IPX5 True Wireless in Ear Bluetooth Earbuds (Black) (ID: B0B31FR4Y2) - https://www.amazon.in/Boult-Audio-Equalizer-Cancellation-Bluetooth/dp/B0B31FR4Y2/ref=sr_1_206?qid=1672903005&s=computers&sr=1-206
# - Zebronics Zeb Buds C2 in Ear Type C Wired Earphones with Mic, Braided 1.2 Metre Cable, Metallic Design, 10mm Drivers, in Line Mic & Volume Controller (Blue) (ID: B08VRMK55F) - https://www.amazon.in/Zeb-Buds-C2-Controller-Blue/dp/B08VRMK55F/ref=sr_1_176?qid=1672903004&s=computers&sr=1-176
# - ZEBRONICS Zeb-Sound Bomb N1 True Wireless in Ear Earbuds with Mic ENC, Gaming Mode (up to 50ms), up to 18H Playback, BT V5.2, Fidget Case, Voice Assistant, Splash Proof, Type C (Midnight Black) (ID: B0B2931FCV) - https://www.amazon.in/Zebronics-Zeb-Sound-N1-Bluetooth-Assistant/dp/B0B2931FCV/ref=sr_1_338?qid=1672903012&s=computers&sr=1-338
# - boAt Airdopes 191G True Wireless Earbuds with ENx™ Tech Equipped Quad Mics, Beast™ Mode(Low Latency- 65ms) for Gaming, 2x6mm Dual Drivers, 30H Playtime, IPX5, IWP™, Appealing Case LEDs(Sport Blue) (ID: B09X76VL5L) - https://www.amazon.in/boAt-Airdopes-191G-Wireless-Appealing/dp/B09X76VL5L/ref=sr_1_301?qid=1672903010&s=computers&sr=1-301
#
# Categoria: Tv
# - Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack),Black (ID: B014I8SX4Y) - https://www.amazon.in/AmazonBasics-High-Speed-Cable-2-Pack-Black/dp/B014I8SX4Y/ref=sr_1_73?qid=1672909128&s=electronics&sr=1-73
# - JBL C100SI Wired In Ear Headphones with Mic, JBL Pure Bass Sound, One Button Multi-function Remote, Premium Metallic Finish, Angled Buds for Comfort fit (Red) (ID: B01DF26V7A) - https://www.amazon.in/JBL-C100SI-Ear-Headphones-Mic/dp/B01DF26V7A/ref=sr_1_159?qid=1672895791&s=electronics&sr=1-159
# - Amazon Basics High-Speed HDMI Cable, 6 Feet - Supports Ethernet, 3D, 4K video,Black (ID: B014I8SSD0) - https://www.amazon.in/AmazonBasics-High-Speed-HDMI-Cable-Feet/dp/B014I8SSD0/ref=sr_1_51?qid=1672909126&s=electronics&sr=1-51
# - TP-Link Tapo 360° 2MP 1080p Full HD Pan/Tilt Home Security Wi-Fi Smart Camera| Alexa Enabled| 2-Way Audio| Night Vision| Motion Detection| Sound and Light Alarm| Indoor CCTV (Tapo C200) White (ID: B07XLML2YS) - https://www.amazon.in/TP-Link-Wireless-Security-Tapo-C200/dp/B07XLML2YS/ref=sr_1_146?qid=1672903002&s=computers&sr=1-146
# - TP-Link AC750 Wifi Range Extender | Up to 750Mbps | Dual Band WiFi Extender, Repeater, Wifi Signal Booster, Access Point| Easy Set-Up | Extends Wifi to Smart Home & Alexa Devices (RE200) (ID: B00KXULGJQ) - https://www.amazon.in/Tp-Link-300Mbps-AC750-Range-Extender/dp/B00KXULGJQ/ref=sr_1_57?qid=1672902997&s=computers&sr=1-57
# - JBL C200SI, Premium in Ear Wired Earphones with Mic, Signature Sound, One Button Multi-Function Remote, Angled Earbuds for Comfort fit (Blue) (ID: B07DFYJRQV) - https://www.amazon.in/JBL-C200SI-Ear-Headphones-Mystic/dp/B07DFYJRQV/ref=sr_1_134?qid=1672903001&s=computers&sr=1-134
# - TP-Link TL-WA850RE Single_Band 300Mbps RJ45 Wireless Range Extender, Broadband/Wi-Fi Extender, Wi-Fi Booster/Hotspot with 1 Ethernet Port, Plug and Play, Built-in Access Point Mode, White (ID: B00A0VCJPI) - https://www.amazon.in/TP-Link-TL-WA850RE-300Mbps-Universal-Extender/dp/B00A0VCJPI/ref=sr_1_127?qid=1672903001&s=computers&sr=1-127
# - AmazonBasics High-Speed Braided HDMI Cable - 3 Feet - Supports Ethernet, 3D, 4K and Audio Return (Black) (ID: B075ZTJ9XR) - https://www.amazon.in/AmazonBasics-Braided-HDMI-Cable-3-Feet/dp/B075ZTJ9XR/ref=sr_1_380?qid=1672909143&s=electronics&sr=1-380
# - Boult Audio AirBass PowerBuds with Inbuilt Powerbank, 120H Total Playtime, IPX7 Fully Waterproof, Lightning Boult Type-C Fast Charging, Low Latency Gaming, TWS Earbuds with Pro+ Calling Mic (Black) (ID: B08D11DZ2W) - https://www.amazon.in/Boult-Audio-PowerBuds-Wireless-Waterproof/dp/B08D11DZ2W/ref=sr_1_69?qid=1672902997&s=computers&sr=1-69
# - BlueRigger Digital Optical Audio Toslink Cable (6 Feet / 1.8 Meter) With 8 Channel (7.1) Audio Support (for Home Theatre, Xbox, Playstation etc.) (ID: B005LJQMZC) - https://www.amazon.in/BlueRigger-Digital-Optical-Toslink-Meters/dp/B005LJQMZC/ref=sr_1_209?qid=1672909134&s=electronics&sr=1-209
# - BlueRigger Digital Optical Audio Toslink Cable (3.3 Feet / 1 Meter) With 8 Channel (7.1) Audio Support (for Home Theatre, Xbox, Playstation etc.) (ID: B005LJQMCK) - https://www.amazon.in/BlueRigger-Digital-Optical-Audio-Toslink/dp/B005LJQMCK/ref=sr_1_167?qid=1672909131&s=electronics&sr=1-167
# - TP-Link AC750 Dual Band Wireless Cable Router, 4 10/100 LAN + 10/100 WAN Ports, Support Guest Network and Parental Control, 750Mbps Speed Wi-Fi, 3 Antennas (Archer C20) Blue, 2.4 GHz (ID: B0759QMF85) - https://www.amazon.in/TP-Link-Archer-C20-Wireless-Router/dp/B0759QMF85/ref=sr_1_187?qid=1672903004&s=computers&sr=1-187
# - Samsung 80 cm (32 Inches) Wondertainment Series HD Ready LED Smart TV UA32T4340BKXXL (Glossy Black) (ID: B09F6S8BT6) - https://www.amazon.in/Samsung-Inches-Wondertainment-UA32T4340BKXXL-Glossy/dp/B09F6S8BT6/ref=sr_1_24?qid=1672909124&s=electronics&sr=1-24
# - Gizga Essentials Cable Organiser, Cord Management System for PC, TV, Home Theater, Speaker & Cables, Reusable Cable Organizer for Desk, WFH Accessories, Organizer Tape Roll, Reusable Cable Ties Strap (ID: B07R99NBVB) - https://www.amazon.in/Essentials-Reusable-Double-Organizer-Length/dp/B07R99NBVB/ref=sr_1_444?qid=1672903017&s=computers&sr=1-444
# - Samsung 80 cm (32 inches) Wondertainment Series HD Ready LED Smart TV UA32TE40AAKBXL (Titan Gray) (ID: B08PV1X771) - https://www.amazon.in/Samsung-inches-Wondertainment-Ready-UA32TE40AAKBXL/dp/B08PV1X771/ref=sr_1_171?qid=1672909133&s=electronics&sr=1-171
# - OnePlus 80 cm (32 inches) Y Series HD Ready Smart Android LED TV 32 Y1S (Black) (ID: B09Q5SWVBJ) - https://www.amazon.in/OnePlus-inches-Ready-Smart-Android/dp/B09Q5SWVBJ/ref=sr_1_63?qid=1672909126&s=electronics&sr=1-63
# - OnePlus 126 cm (50 inches) Y Series 4K Ultra HD Smart Android LED TV 50Y1S Pro (Black) (ID: B0B3MMYHYW) - https://www.amazon.in/OnePlus-50-inches-Android-Pro/dp/B0B3MMYHYW/ref=sr_1_42?qid=1672909125&s=electronics&sr=1-42
# - Zebronics Zeb-JUKEBAR 3900, 80W Multimedia soundbar with subwoofer Supporting Bluetooth, HDMI(ARC), Coaxial Input, AUX, USB & Remote Control (Black) (ID: B08CRRQK6Z) - https://www.amazon.in/Zebronics-Zeb-JUKEBAR-3900-Multimedia-Supporting/dp/B08CRRQK6Z/ref=sr_1_366?qid=1672903013&s=computers&sr=1-366
# - Samsung 80 cm (32 Inches) Wondertainment Series HD Ready LED Smart TV UA32T4340BKXXL (Glossy Black) (ID: B09F6S8BT6) - https://www.amazon.in/Samsung-Inches-Wondertainment-UA32T4340BKXXL-Glossy/dp/B09F6S8BT6/ref=sr_1_150?qid=1672903002&s=computers&sr=1-150
# - TCL 100 cm (40 inches) Full HD Certified Android R Smart LED TV 40S6505 (Black) (ID: B09T3KB6JZ) - https://www.amazon.in/TCL-inches-Certified-Android-40S6505/dp/B09T3KB6JZ/ref=sr_1_103?qid=1672909129&s=electronics&sr=1-103
# - 10k 8k 4k HDMI Cable, Certified 48Gbps 1ms Ultra High Speed HDMI 2.1 Cable 4k 120Hz 144Hz 2k 165Hz 8k 60Hz Dynamic HDR ARC eARC DTS:X Compatible for Mac Gaming PC Soundbar TV Monitor Laptop PS5 4 Xbox (ID: B08TGG316Z) - https://www.amazon.in/Cable-Certified-48Gbps-Ultra-Dynamic/dp/B08TGG316Z/ref=sr_1_156?qid=1672909131&s=electronics&sr=1-156
# - TCL 108 cm (43 inches) 4K Ultra HD Certified Android Smart LED TV 43P615 (Black) (ID: B08FD2VSD9) - https://www.amazon.in/TCL-inches-Certified-Android-43P615/dp/B08FD2VSD9/ref=sr_1_490?qid=1672909149&s=electronics&sr=1-490
# - Boult Audio Airbass Z20 True Wireless, 40H Battery Life, Zen ENC Mic, Type-C Lightning Boult Fast Charging (10Mins=100Mins), BoomX Tech Bass, ENC, IPX5 in Ear Earbuds with mic (Green) (ID: B0B31BYXQQ) - https://www.amazon.in/Boult-Audio-Lightning-Environmental-Cancellation/dp/B0B31BYXQQ/ref=sr_1_50?qid=1672902997&s=computers&sr=1-50
# - FEDUS Cat6 Ethernet Cable, 10 Meter High Speed 550MHZ / 10 Gigabit Speed UTP LAN Cable, Network Cable Internet Cable RJ45 Cable LAN Wire, Patch Computer Cord Gigabit Category 6 Wires for Modem, Router (ID: B01DGVKBC6) - https://www.amazon.in/Technotech-Ethernet-Network-Patch-Cable/dp/B01DGVKBC6/ref=sr_1_270?qid=1672903008&s=computers&sr=1-270
# - boAt Type C A750 Stress Resistant, Tangle-free, Sturdy Flat Cable with 6.5A Fast Charging & 480Mbps Data Transmission, 10000+ Bends Lifespan and Extended 1.5m Length(Rebellious Black) (ID: B09RWZRCP1) - https://www.amazon.in/boAt-A750-Tangle-free-Transmission-Rebellious/dp/B09RWZRCP1/ref=sr_1_449?qid=1672903017&s=computers&sr=1-449
# - Rts™ High Speed 3D Full HD 1080p Support (10 Meters) HDMI Male to HDMI Male Cable TV Lead 1.4V for All Hdmi Devices- Black (10M - 30 FEET) (ID: B0718ZN31Q) - https://www.amazon.in/RTSTM-Support-10-Meters-Devices/dp/B0718ZN31Q/ref=sr_1_249?qid=1672909136&s=electronics&sr=1-249
# - LG 80 cm (32 inches) HD Ready Smart LED TV 32LQ576BPSA (Ceramic Black) (ID: B09YL9SN9B) - https://www.amazon.in/LG-inches-Ready-32LQ576BPSA-Ceramic/dp/B09YL9SN9B/ref=sr_1_125?qid=1672909130&s=electronics&sr=1-125
# - PROLEGEND® PL-T002 Universal TV Stand Table Top for Most 22 to 65 inch LCD Flat Screen TV, VESA up to 800 by 400mm (ID: B09HN7LD5L) - https://www.amazon.in/PROLEGEND%C2%AE-PL-T002-Universal-Stand-Screen/dp/B09HN7LD5L/ref=sr_1_465?qid=1672909147&s=electronics&sr=1-465
# - CableCreation RCA to 3.5mm Male Audio Cable, 3.5mm to 2RCA Cable Male RCA Cable,Y Splitter Stereo Jack Cable for Home Theater,Subwoofer, Receiver, Speakers and More (3Feet/0.9Meter,Black) (ID: B06XFTHCNY) - https://www.amazon.in/Cablecreation-Audio-Cable-3-5mm-2-Male/dp/B06XFTHCNY/ref=sr_1_305?qid=1672909139&s=electronics&sr=1-305
# - Fire-Boltt Tank 1.85" Bluetooth Calling Smart Watch, 123 Sports Mode, 8 UI Interactions, Built in Speaker & Mic, 7 Days Battery & Fire-Boltt Health Suite (ID: B0BNXFDTZ2) - https://www.amazon.in/Fire-Boltt-Bluetooth-Calling-Interactions-Speaker/dp/B0BNXFDTZ2/ref=sr_1_486?qid=1672895894&s=electronics&sr=1-486
# - Airtel Digital TV HD Set Top Box with 1 Month Basic Pack with Recording + Free Standard Installation (ID: B075TJHWVC) - https://www.amazon.in/Airtel-Digital-TV-Month-Recording/dp/B075TJHWVC/ref=sr_1_407_mod_primary_new?qid=1672909144&s=electronics&sbo=RZvfv%2F%2FHxDF%2BO5021pAnSA%3D%3D&sr=1-407
# - KRISONS Thunder Speaker, Multimedia Home Theatre, Floor Standing Speaker, LED Display with Bluetooth, FM, USB, Micro SD Card, AUX Connectivity (ID: B09LRZYBH1) - https://www.amazon.in/KRISONS-Multimedia-Standing-Bluetooth-Connectivity/dp/B09LRZYBH1/ref=sr_1_388?qid=1672909144&s=electronics&sr=1-388
# - WANBO X1 Pro (Upgraded) | Native 1080P Full HD | Android 9 | Projector for Home | LED Cinema | 350ANSI | 3900 lumens | WiFi Bluetooth | HDMI ARC | Dolby DTS | 4D Keystone Correction (Global Version) (ID: B0BNDD9TN6) - https://www.amazon.in/WANBO-X1-Pro-Projector-Correction/dp/B0BNDD9TN6/ref=sr_1_466?qid=1672909147&s=electronics&sr=1-466
# - Acer 80 cm (32 inches) S Series HD Ready Android Smart LED TV AR32AR2841HDSB (Black) (ID: B0B9959XF3) - https://www.amazon.in/Acer-inches-Ready-Android-AR32AR2841HDSB/dp/B0B9959XF3/ref=sr_1_188?qid=1672909133&s=electronics&sr=1-188
# - boAt Type C A750 Stress Resistant, Tangle-free, Sturdy Flat Cable with 6.5A Fast Charging & 480Mbps Data Transmission, 10000+ Bends Lifespan and Extended 1.5m Length(Radiant Red) (ID: B09RX1FK54) - https://www.amazon.in/boAt-A750-Resistant-Tangle-free-Transmission/dp/B09RX1FK54/ref=sr_1_126?qid=1672909130&s=electronics&sr=1-126
# - Qubo Smart Cam 360 from Hero Group | Made in India | 2MP 1080p Full HD | CCTV Wi-Fi Camera | 360 Degree Coverage| Two Way Talk | Mobile App Connectivity | Night Vision | Cloud & SD Card Recording (ID: B09LD3116F) - https://www.amazon.in/Smart-Camera-Coverage-Intruder-Google/dp/B09LD3116F/ref=sr_1_357?qid=1672903012&s=computers&sr=1-357
# - TCL 80 cm (32 inches) HD Ready Certified Android Smart LED TV 32S5205 (Black) (ID: B09ZPM4C2C) - https://www.amazon.in/TCL-inches-Certified-Android-32S5205/dp/B09ZPM4C2C/ref=sr_1_86?qid=1672909128&s=electronics&sr=1-86
# - Samsung 24-inch(60.46cm) FHD Monitor, IPS, 75 Hz, Bezel Less Design, AMD FreeSync, Flicker Free, HDMI, D-sub, (LF24T350FHWXXL, Dark Blue Gray) (ID: B08J82K4GX) - https://www.amazon.in/Samsung-inch-Bezel-Flicker-Monitor-LF24T350FHWXXL/dp/B08J82K4GX/ref=sr_1_379?qid=1672903013&s=computers&sr=1-379
# - Airtel Digital TV HD Set Top Box with FTA Pack | Unlimited Entertainment + Recording Feature + Free Standard Installation (6 Months Pack) (ID: B0B8VQ7KDS) - https://www.amazon.in/Airtel-Pack-Entertainment-Installation-Months/dp/B0B8VQ7KDS/ref=sr_1_497?qid=1672909149&s=electronics&sr=1-497
# - Cubetek 3 in 1 LCD Display V5.0 Bluetooth Transmitter Receiver, Bypass Audio Adapter with Aux, Optical, Dual Link Support for TV, Home Stereo, PC, Headphones, Speakers, Model: CB-BT27 (ID: B0978V2CP6) - https://www.amazon.in/Bluetooth-Transmitter-Receiver-Headphones-Speakers/dp/B0978V2CP6/ref=sr_1_385?qid=1672909144&s=electronics&sr=1-385
# - Model-P4 6 Way Swivel Tilt Wall Mount 32-55-inch Full Motion Cantilever for LED,LCD and Plasma TV's (ID: B07966M8XH) - https://www.amazon.in/Model-P4-Swivel-32-55-inch-Motion-Cantilever/dp/B07966M8XH/ref=sr_1_76?qid=1672909128&s=electronics&sr=1-76
# - boAt Newly Launched Wave Electra with 1.81" HD Display, Smart Calling with Ultra-Seamless BT Calling Chip,20 Built-In Watch Faces,100 + Sports Modes,Menu Personalization,In-Built Games(Charcoal Black) (ID: B0BNV7JM5Y) - https://www.amazon.in/boAt-Launched-Ultra-Seamless-Personalization-Charcoal/dp/B0BNV7JM5Y/ref=sr_1_133?qid=1672895784&s=electronics&sr=1-133
# - VU 138 cm (55 inches) Premium Series 4K Ultra HD Smart IPS LED TV 55UT (Black) (ID: B0BB3CBFBM) - https://www.amazon.in/VU-inches-Premium-Ultra-Smart/dp/B0BB3CBFBM/ref=sr_1_169?qid=1672909133&s=electronics&sr=1-169
# - Kodak 80 cm (32 inches) HD Ready Certified Android Smart LED TV 32HDX7XPROBL (Black) (ID: B09DSXK8JX) - https://www.amazon.in/Kodak-inches-Certified-Android-32HDX7XPROBL/dp/B09DSXK8JX/ref=sr_1_494?qid=1672909149&s=electronics&sr=1-494
# - WZATCO Pixel | Portable LED Projector | Native 720p with Full HD 1080P Support | 2000 Lumens (200 ANSI) | 176" Large Screen | Projector for Home and Outdoor | Compatible with TV Stick, PC, PS4 (ID: B0BLV1GNLN) - https://www.amazon.in/WZATCO-Pixel-Portable-Projector-Compatible/dp/B0BLV1GNLN/ref=sr_1_231?qid=1672909135&s=electronics&sr=1-231
# - Hisense 126 cm (50 inches) Bezelless Series 4K Ultra HD Smart LED Google TV 50A6H (Black) (ID: B0B2C5MJN6) - https://www.amazon.in/Hisense-inches-Bezelless-Google-50A6H/dp/B0B2C5MJN6/ref=sr_1_456?qid=1672909146&s=electronics&sr=1-456
# - boAt Type C A750 Stress Resistant, Tangle-free, Sturdy Flat Cable with 6.5A Fast Charging & 480Mbps Data Transmission, 10000+ Bends Lifespan and Extended 1.5m Length(Rebellious Black) (ID: B09RWZRCP1) - https://www.amazon.in/boAt-A750-Tangle-free-Transmission-Rebellious/dp/B09RWZRCP1/ref=sr_1_83?qid=1672909128&s=electronics&sr=1-83
# - Bestor ® 8K Hdmi 2.1 Cable 48Gbps 9.80Ft/Ultra High Speed Hdmi Braided Cord For Roku Tv/Ps5/Hdtv/Blu-Ray Projector, Laptop, Television, Personal Computer, Xbox, Ps4, Ps5, Ps4 Pro (1 M, Grey) (ID: B09HCH3JZG) - https://www.amazon.in/BESTOR%C2%AE-48Gbps-9-80FT-Braided-Cord-4K/dp/B09HCH3JZG/ref=sr_1_478?qid=1672909147&s=electronics&sr=1-478
# - CP PLUS 2MP Full HD Smart Wi-fi CCTV Security Camera | 360° with Pan Tilt | Two Way Talk | Cloud Monitor | Motion Detect | Night Vision | Supports SD Card (Up to 128 GB) | Alexa & Ok Google | CP-E21A (ID: B09NNHFSSF) - https://www.amazon.in/CP-PLUS-Intelligent-Compatible-Communication/dp/B09NNHFSSF/ref=sr_1_316?qid=1672903011&s=computers&sr=1-316
# - TCL 80 cm (32 inches) HD Ready Certified Android Smart LED TV 32S615 (Black) (ID: B09ZPJT8B2) - https://www.amazon.in/TCL-inches-Certified-Android-32S615/dp/B09ZPJT8B2/ref=sr_1_227?qid=1672909135&s=electronics&sr=1-227
# 0

# %%
# Função para visualizar os sinônimos mapeados por categoria
def visualizar_sinonimos_por_categoria(categorias_sinonimos):
    for categoria, sinonimos in categorias_sinonimos.items():
        print(f"\n Categoria: {categoria}")
        print(f"*** Sinônimos detectados ({len(sinonimos)}):")
        print(", ".join(sorted(sinonimos)))

# Chamada da função
visualizar_sinonimos_por_categoria(categorias_sinonimos)
# Out:
#  Categoria: home&kitchen|heating,cooling&airquality|fans|exhaustfans
# *** Sinônimos detectados (52):
# abode, base, buff, chill, chilling, cool, cool down, cool off, cooling, cooling system, devotee, domicile, dwelling, dwelling house, exhaustfans, family, fan, fans, fire up, habitation, heat, heat up, heating, heating plant, heating system, heating,cooling&airquality, home, home base, home plate, home&kitchen, hot up, house, household, ignite, inflame, interior, internal, kitchen, lover, menage, national, nursing home, place, plate, rest home, rooter, sports fan, stir up, temperature reduction, wake, warming, winnow
#
#  Categoria: officeproducts|officepaperproducts|paper|stationery|notebooks,writingpads&diaries|wireboundnotebooks
# *** Sinônimos detectados (17):
# composition, diary, journal, letter paper, newspaper, newspaper publisher, notebook, notebook computer, notebooks,writingpads&diaries, officepaperproducts, officeproducts, paper, report, stationery, theme, wallpaper, wireboundnotebooks
#
#  Categoria: electronics|hometheater,tv&video|accessories|3dglasses
# *** Sinônimos detectados (25):
# 3dglasses, TV, accessary, accessories, accessory, accouterment, accoutrement, add-on, appurtenance, boob tube, electronics, goggle box, hometheater,tv&video, idiot box, picture, supplement, telecasting, television, television receiver, television set, telly, tv, tv set, video, video recording
#
#  Categoria: electronics|mobiles&accessories|mobileaccessories|chargers|wallchargers
# *** Sinônimos detectados (18):
# Mobile, Mobile River, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, battery charger, charger, chargers, courser, electronics, mobile, mobileaccessories, mobiles&accessories, supplement, wallchargers
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|yogurtmakers
# *** Sinônimos detectados (25):
# abode, base, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, smallkitchenappliances, yogurtmakers
#
#  Categoria: computers&accessories|accessories&peripherals|pcgamingperipherals|gamingmice
# *** Sinônimos detectados (24):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, gamingmice, information processing system, pcgamingperipherals, peripheral, peripheral device, reckoner, supplement
#
#  Categoria: computers&accessories|accessories&peripherals|tabletaccessories|stands
# *** Sinônimos detectados (53):
# abide, accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, bandstand, base, bear, brook, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, digest, electronic computer, endure, estimator, fend, figurer, information processing system, outdoor stage, pedestal, peripheral, peripheral device, place upright, point of view, put up, rack, reckoner, remain firm, resist, sales booth, stall, stand, stand up, standpoint, stands, standstill, stick out, stomach, suffer, supplement, support, tabletaccessories, tie-up, tolerate, viewpoint
#
#  Categoria: computers&accessories|printers,inks&accessories|printers
# *** Sinônimos detectados (24):
# accessary, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, ink, pressman, printer, printers, printers,inks&accessories, printing machine, reckoner, supplement
#
#  Categoria: electronics|wearabletechnology|smartwatches
# *** Sinônimos detectados (3):
# electronics, smartwatches, wearabletechnology
#
#  Categoria: home&kitchen|kitchen&homeappliances|sewingmachines&accessories|sewing&embroiderymachines
# *** Sinônimos detectados (41):
# abode, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, base, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, run up, sew, sew together, sewing, sewing&embroiderymachines, sewingmachines&accessories, stitch, stitchery, stitching, supplement, tailor, tailor-make
#
#  Categoria: electronics|homeaudio|speakers|outdoorspeakers
# *** Sinônimos detectados (14):
# Speaker, electronics, homeaudio, loudspeaker, loudspeaker system, outdoorspeakers, speaker, speaker system, speaker unit, speakers, talker, utterer, verbaliser, verbalizer
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|mills&grinders|wetgrinders
# *** Sinônimos detectados (58):
# Cuban sandwich, Italian sandwich, James Mill, John Mill, John Stuart Mill, Mill, Mills, Robert Mills, abode, base, bomber, domicile, dwelling, dwelling house, factory, family, grind, grinder, habitation, hero, hero sandwich, hoagie, hoagy, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, manufactory, manufacturing plant, menage, mill, mill about, mill around, milling machinery, mills&grinders, molar, national, nursing home, place, plate, poor boy, pulverisation, pulverization, rest home, smallkitchenappliances, sub, submarine, submarine sandwich, torpedo, wedge, wetgrinders, zep
#
#  Categoria: home&kitchen|heating,cooling&airquality|airpurifiers|hepaairpurifiers
# *** Sinônimos detectados (45):
# abode, airpurifiers, base, chill, chilling, cool, cool down, cool off, cooling, cooling system, domicile, dwelling, dwelling house, family, fire up, habitation, heat, heat up, heating, heating plant, heating system, heating,cooling&airquality, hepaairpurifiers, home, home base, home plate, home&kitchen, hot up, house, household, ignite, inflame, interior, internal, kitchen, menage, national, nursing home, place, plate, rest home, stir up, temperature reduction, wake, warming
#
#  Categoria: computers&accessories|accessories&peripherals|keyboards,mice&inputdevices|mice
# *** Sinônimos detectados (29):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, black eye, calculator, computer, computer mouse, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, keyboard, keyboards,mice&inputdevices, mice, mouse, peripheral, peripheral device, reckoner, shiner, supplement
#
#  Categoria: electronics|accessories|memorycards|securedigitalcards
# *** Sinônimos detectados (11):
# accessary, accessories, accessory, accouterment, accoutrement, add-on, appurtenance, electronics, memorycards, securedigitalcards, supplement
#
#  Categoria: computers&accessories|accessories&peripherals|pcgamingperipherals|gamepads
# *** Sinônimos detectados (24):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, gamepads, information processing system, pcgamingperipherals, peripheral, peripheral device, reckoner, supplement
#
#  Categoria: computers&accessories|accessories&peripherals|adapters|usbtousbadapters
# *** Sinônimos detectados (28):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, adapter, adapters, adaptor, add-on, appurtenance, arranger, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, peripheral, peripheral device, reckoner, supplement, transcriber, usbtousbadapters
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|eggboilers
# *** Sinônimos detectados (25):
# abode, base, domicile, dwelling, dwelling house, eggboilers, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, smallkitchenappliances
#
#  Categoria: electronics|mobiles&accessories|smartphones&basicmobiles|basicmobiles
# *** Sinônimos detectados (14):
# Mobile, Mobile River, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, basicmobiles, electronics, mobile, mobiles&accessories, smartphones&basicmobiles, supplement
#
#  Categoria: computers&accessories|accessories&peripherals|cables&accessories|cables|satacables
# *** Sinônimos detectados (37):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, cable, cable length, cable system, cable television, cable television service, cable's length, cablegram, cables, cables&accessories, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, line, overseas telegram, peripheral, peripheral device, reckoner, satacables, supplement, telegraph, transmission line, wire
#
#  Categoria: home&kitchen|heating,cooling&airquality|fans|ceilingfans
# *** Sinônimos detectados (52):
# abode, base, buff, ceilingfans, chill, chilling, cool, cool down, cool off, cooling, cooling system, devotee, domicile, dwelling, dwelling house, family, fan, fans, fire up, habitation, heat, heat up, heating, heating plant, heating system, heating,cooling&airquality, home, home base, home plate, home&kitchen, hot up, house, household, ignite, inflame, interior, internal, kitchen, lover, menage, national, nursing home, place, plate, rest home, rooter, sports fan, stir up, temperature reduction, wake, warming, winnow
#
#  Categoria: homeimprovement|electrical|adapters&multi-outlets
# *** Sinônimos detectados (22):
# adapter, adapters&multi-outlets, adaptor, arranger, electric, electric outlet, electric receptacle, electrical, electrical outlet, exit, homeimprovement, issue, mercantile establishment, outlet, release, retail store, sales outlet, transcriber, vent, wall plug, wall socket, way out
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|juicers
# *** Sinônimos detectados (31):
# abode, base, domicile, drinker, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, imbiber, interior, internal, juice reamer, juicer, juicers, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, reamer, rest home, smallkitchenappliances, toper
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|mixergrinders
# *** Sinônimos detectados (25):
# abode, base, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, menage, mixergrinders, national, nursing home, place, plate, rest home, smallkitchenappliances
#
#  Categoria: computers&accessories|accessories&peripherals|audio&videoaccessories|pcmicrophones
# *** Sinônimos detectados (29):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, audio, audio frequency, audio recording, audio&videoaccessories, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, pcmicrophones, peripheral, peripheral device, reckoner, sound, sound recording, supplement
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|juicers|coldpressjuicers
# *** Sinônimos detectados (32):
# abode, base, coldpressjuicers, domicile, drinker, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, imbiber, interior, internal, juice reamer, juicer, juicers, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, reamer, rest home, smallkitchenappliances, toper
#
#  Categoria: officeproducts|officepaperproducts|paper|stationery|pens,pencils&writingsupplies|pens&refills|gelinkrollerballpens
# *** Sinônimos detectados (24):
# compose, composition, fill again, gelinkrollerballpens, indite, letter paper, newspaper, newspaper publisher, officepaperproducts, officeproducts, paper, pen, pencil, penitentiary, pens&refills, pens,pencils&writingsupplies, playpen, refill, replenish, report, stationery, theme, wallpaper, write
#
#  Categoria: electronics|mobiles&accessories|mobileaccessories|cases&covers|basiccases
# *** Sinônimos detectados (98):
# Mobile, Mobile River, accessary, accessory, accouterment, accoutrement, add-on, address, appurtenance, back, basiccases, binding, blanket, book binding, breed, brood, case, caseful, cases&covers, casing, causa, cause, character, compensate, compositor's case, comprehend, concealment, continue, cover, cover charge, cover song, cover up, cover version, covering, covering fire, covert, cross, cut across, cut through, deal, display case, eccentric, electronics, embrace, encase, encompass, enshroud, event, example, extend, face, font, fount, get across, get over, grammatical case, guinea pig, handle, hatch, hide, incase, incubate, instance, insure, lawsuit, masking, mobile, mobileaccessories, mobiles&accessories, natural covering, overcompensate, overlay, pass over, pillow slip, pillowcase, plow, report, screen, screening, sheath, shell, showcase, shroud, slip, spread over, subject, suit, supplement, top, track, traverse, treat, type, typeface, typesetter's case, underwrite, vitrine, wrap up
#
#  Categoria: electronics|mobiles&accessories|mobileaccessories|automobileaccessories|cradles
# *** Sinônimos detectados (21):
# Mobile, Mobile River, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, automobileaccessories, birthplace, cradle, cradles, electronics, mobile, mobileaccessories, mobiles&accessories, place of origin, provenance, provenience, rocker, supplement
#
#  Categoria: electronics|homeaudio|speakers|multimediaspeakersystems
# *** Sinônimos detectados (14):
# Speaker, electronics, homeaudio, loudspeaker, loudspeaker system, multimediaspeakersystems, speaker, speaker system, speaker unit, speakers, talker, utterer, verbaliser, verbalizer
#
#  Categoria: electronics|homeaudio|accessories|speakeraccessories|mounts
# *** Sinônimos detectados (31):
# accessary, accessories, accessory, accouterment, accoutrement, add-on, appurtenance, backing, bestride, climb, climb on, climb up, electronics, get on, go up, homeaudio, hop on, jump on, mount, mount up, mountain, mounts, put on, ride, riding horse, rise, saddle horse, setting, speakeraccessories, supplement, wax
#
#  Categoria: electronics|cameras&photography|accessories|batteries&chargers|batterychargers
# *** Sinônimos detectados (29):
# accessary, accessories, accessory, accouterment, accoutrement, add-on, appurtenance, assault and battery, barrage, barrage fire, batteries&chargers, battery, battery charger, batterychargers, bombardment, camera, cameras&photography, charger, courser, electric battery, electronics, photographic camera, photography, picture taking, shelling, stamp battery, supplement, television camera, tv camera
#
#  Categoria: electronics|hometheater,tv&video|accessories|cables|rcacables
# *** Sinônimos detectados (38):
# TV, accessary, accessories, accessory, accouterment, accoutrement, add-on, appurtenance, boob tube, cable, cable length, cable system, cable television, cable television service, cable's length, cablegram, cables, electronics, goggle box, hometheater,tv&video, idiot box, line, overseas telegram, picture, rcacables, supplement, telecasting, telegraph, television, television receiver, television set, telly, transmission line, tv, tv set, video, video recording, wire
#
#  Categoria: homeimprovement|electrical|cordmanagement
# *** Sinônimos detectados (4):
# cordmanagement, electric, electrical, homeimprovement
#
#  Categoria: home&kitchen|craftmaterials|paintingmaterials
# *** Sinônimos detectados (24):
# abode, base, craftmaterials, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, menage, national, nursing home, paintingmaterials, place, plate, rest home
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|juicermixergrinders
# *** Sinônimos detectados (25):
# abode, base, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, juicermixergrinders, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, smallkitchenappliances
#
#  Categoria: health&personalcare|homemedicalsupplies&equipment|healthmonitors|weighingscales|digitalbathroomscales
# *** Sinônimos detectados (8):
# digitalbathroomscales, equipment, health, health&personalcare, healthmonitors, homemedicalsupplies&equipment, weighingscales, wellness
#
#  Categoria: officeproducts|officepaperproducts|paper|stationery|pens,pencils&writingsupplies|pens&refills|stickballpointpens
# *** Sinônimos detectados (24):
# compose, composition, fill again, indite, letter paper, newspaper, newspaper publisher, officepaperproducts, officeproducts, paper, pen, pencil, penitentiary, pens&refills, pens,pencils&writingsupplies, playpen, refill, replenish, report, stationery, stickballpointpens, theme, wallpaper, write
#
#  Categoria: home&kitchen|heating,cooling&airquality|airconditioners|split-systemairconditioners
# *** Sinônimos detectados (68):
# Split, abode, airconditioners, base, break, break open, break up, burst, carve up, chill, chilling, cleave, cool, cool down, cool off, cooling, cooling system, disconnected, dissever, disunited, divide, domicile, dwelling, dwelling house, family, fire up, fragmented, habitation, heat, heat up, heating, heating plant, heating system, heating,cooling&airquality, home, home base, home plate, home&kitchen, hot up, house, household, ignite, inflame, interior, internal, kitchen, menage, national, nursing home, part, place, plate, rent, rest home, rip, rive, schism, separate, snag, split, split up, split-systemairconditioners, stir up, stock split, tear, temperature reduction, wake, warming
#
#  Categoria: home&kitchen|heating,cooling&airquality|roomheaters|fanheaters
# *** Sinônimos detectados (45):
# abode, base, chill, chilling, cool, cool down, cool off, cooling, cooling system, domicile, dwelling, dwelling house, family, fanheaters, fire up, habitation, heat, heat up, heating, heating plant, heating system, heating,cooling&airquality, home, home base, home plate, home&kitchen, hot up, house, household, ignite, inflame, interior, internal, kitchen, menage, national, nursing home, place, plate, rest home, roomheaters, stir up, temperature reduction, wake, warming
#
#  Categoria: computers&accessories|accessories&peripherals|cables&accessories|cables|dvicables
# *** Sinônimos detectados (37):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, cable, cable length, cable system, cable television, cable television service, cable's length, cablegram, cables, cables&accessories, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, dvicables, electronic computer, estimator, figurer, information processing system, line, overseas telegram, peripheral, peripheral device, reckoner, supplement, telegraph, transmission line, wire
#
#  Categoria: electronics|homeaudio|accessories|adapters
# *** Sinônimos detectados (15):
# accessary, accessories, accessory, accouterment, accoutrement, adapter, adapters, adaptor, add-on, appurtenance, arranger, electronics, homeaudio, supplement, transcriber
#
#  Categoria: computers&accessories|accessories&peripherals|pcgamingperipherals|gamingkeyboards
# *** Sinônimos detectados (24):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, gamingkeyboards, information processing system, pcgamingperipherals, peripheral, peripheral device, reckoner, supplement
#
#  Categoria: computers&accessories|accessories&peripherals|audio&videoaccessories|webcams&voipequipment|webcams
# *** Sinônimos detectados (31):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, audio, audio frequency, audio recording, audio&videoaccessories, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, peripheral, peripheral device, reckoner, sound, sound recording, supplement, webcam, webcams, webcams&voipequipment
#
#  Categoria: home&kitchen|kitchen&homeappliances|waterpurifiers&accessories|waterfilters&purifiers
# *** Sinônimos detectados (33):
# abode, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, base, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, purifier, rest home, supplement, waterfilters&purifiers, waterpurifiers&accessories
#
#  Categoria: home&kitchen|heating,cooling&airquality|humidifiers
# *** Sinônimos detectados (44):
# abode, base, chill, chilling, cool, cool down, cool off, cooling, cooling system, domicile, dwelling, dwelling house, family, fire up, habitation, heat, heat up, heating, heating plant, heating system, heating,cooling&airquality, home, home base, home plate, home&kitchen, hot up, house, household, humidifiers, ignite, inflame, interior, internal, kitchen, menage, national, nursing home, place, plate, rest home, stir up, temperature reduction, wake, warming
#
#  Categoria: electronics|hometheater,tv&video|accessories|cables|hdmicables
# *** Sinônimos detectados (38):
# TV, accessary, accessories, accessory, accouterment, accoutrement, add-on, appurtenance, boob tube, cable, cable length, cable system, cable television, cable television service, cable's length, cablegram, cables, electronics, goggle box, hdmicables, hometheater,tv&video, idiot box, line, overseas telegram, picture, supplement, telecasting, telegraph, television, television receiver, television set, telly, transmission line, tv, tv set, video, video recording, wire
#
#  Categoria: computers&accessories|accessories&peripherals|usbgadgets|lamps
# *** Sinônimos detectados (25):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, lamp, lamps, peripheral, peripheral device, reckoner, supplement, usbgadgets
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|smallapplianceparts&accessories
# *** Sinônimos detectados (32):
# abode, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, base, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, smallapplianceparts&accessories, smallkitchenappliances, supplement
#
#  Categoria: electronics|homeaudio|speakers|soundbarspeakers
# *** Sinônimos detectados (14):
# Speaker, electronics, homeaudio, loudspeaker, loudspeaker system, soundbarspeakers, speaker, speaker system, speaker unit, speakers, talker, utterer, verbaliser, verbalizer
#
#  Categoria: home&kitchen|craftmaterials|scrapbooking|tape
# *** Sinônimos detectados (33):
# abode, base, craftmaterials, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, mag tape, magnetic tape, menage, national, nursing home, place, plate, record, rest home, scrapbooking, tape, tape measure, tape recording, tapeline, taping, videotape
#
#  Categoria: home&kitchen|craftmaterials|drawingmaterials|drawingmedia|pens
# *** Sinônimos detectados (32):
# abode, base, compose, craftmaterials, domicile, drawingmaterials, drawingmedia, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, indite, interior, internal, kitchen, menage, national, nursing home, pen, penitentiary, pens, place, plate, playpen, rest home, write
#
#  Categoria: computers&accessories|laptops|traditionallaptops
# *** Sinônimos detectados (22):
# accessary, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, laptop, laptop computer, laptops, reckoner, supplement, traditionallaptops
#
#  Categoria: electronics|headphones,earbuds&accessories|cases
# *** Sinônimos detectados (46):
# accessary, accessory, accouterment, accoutrement, add-on, appurtenance, case, caseful, cases, casing, causa, cause, character, compositor's case, display case, earphone, earpiece, eccentric, electronics, encase, event, example, face, font, fount, grammatical case, guinea pig, headphone, headphones,earbuds&accessories, incase, instance, lawsuit, phone, pillow slip, pillowcase, sheath, shell, showcase, slip, subject, suit, supplement, type, typeface, typesetter's case, vitrine
#
#  Categoria: officeproducts|officepaperproducts|paper|stationery|notebooks,writingpads&diaries
# *** Sinônimos detectados (16):
# composition, diary, journal, letter paper, newspaper, newspaper publisher, notebook, notebook computer, notebooks,writingpads&diaries, officepaperproducts, officeproducts, paper, report, stationery, theme, wallpaper
#
#  Categoria: computers&accessories|accessories&peripherals|laptopaccessories|coolingpads
# *** Sinônimos detectados (24):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, coolingpads, data processor, electronic computer, estimator, figurer, information processing system, laptopaccessories, peripheral, peripheral device, reckoner, supplement
#
#  Categoria: home&kitchen|kitchen&homeappliances|vacuum,cleaning&ironing|vacuums&floorcare|vacuums|canistervacuums
# *** Sinônimos detectados (50):
# abode, base, canistervacuums, clean, clean house, cleaning, cleanse, cleansing, cleanup, domicile, dwelling, dwelling house, emptiness, family, habitation, home, home base, home plate, home&kitchen, hoover, house, houseclean, household, interior, internal, iron, iron out, ironing, kitchen, kitchen&homeappliances, make clean, menage, national, nursing home, pick, place, plate, press, rest home, scavenge, strip, vacancy, vacuity, vacuum, vacuum cleaner, vacuum,cleaning&ironing, vacuum-clean, vacuums, vacuums&floorcare, void
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|rotimakers
# *** Sinônimos detectados (25):
# abode, base, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, rotimakers, smallkitchenappliances
#
#  Categoria: computers&accessories|accessories&peripherals|audio&videoaccessories|pcheadsets
# *** Sinônimos detectados (29):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, audio, audio frequency, audio recording, audio&videoaccessories, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, pcheadsets, peripheral, peripheral device, reckoner, sound, sound recording, supplement
#
#  Categoria: computers&accessories|externaldevices&datastorage|externalsolidstatedrives
# *** Sinônimos detectados (20):
# accessary, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, externaldevices&datastorage, externalsolidstatedrives, figurer, information processing system, reckoner, supplement
#
#  Categoria: computers&accessories|externaldevices&datastorage|externalharddisks
# *** Sinônimos detectados (20):
# accessary, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, externaldevices&datastorage, externalharddisks, figurer, information processing system, reckoner, supplement
#
#  Categoria: electronics|mobiles&accessories|mobileaccessories|maintenance,upkeep&repairs|screenprotectors
# *** Sinônimos detectados (54):
# Mobile, Mobile River, accessary, accessory, accouterment, accoutrement, add-on, alimony, amend, animate, appurtenance, bushel, care, compensate, criminal maintenance, doctor, electronics, fix, fixing, fixture, furbish up, hangout, haunt, indemnify, maintenance, maintenance,upkeep&repairs, mend, mending, mobile, mobileaccessories, mobiles&accessories, quicken, reanimate, recompense, recreate, rectify, remediate, remedy, renovate, repair, reparation, resort, restore, revive, revivify, screenprotectors, stamping ground, supplement, sustainment, sustenance, sustentation, touch on, upkeep, vivify
#
#  Categoria: officeproducts|officeelectronics|calculators|financial&business
# *** Sinônimos detectados (28):
# business, business concern, business enterprise, business organisation, business organization, business sector, byplay, calculating machine, calculator, calculators, clientele, commercial enterprise, computer, concern, estimator, figurer, financial, financial&business, fiscal, job, line, line of work, occupation, officeelectronics, officeproducts, patronage, reckoner, stage business
#
#  Categoria: electronics|poweraccessories|surgeprotectors
# *** Sinônimos detectados (3):
# electronics, poweraccessories, surgeprotectors
#
#  Categoria: electronics|hometheater,tv&video|satelliteequipment|satellitereceivers
# *** Sinônimos detectados (18):
# TV, boob tube, electronics, goggle box, hometheater,tv&video, idiot box, picture, satelliteequipment, satellitereceivers, telecasting, television, television receiver, television set, telly, tv, tv set, video, video recording
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|pop-uptoasters
# *** Sinônimos detectados (55):
# abode, base, belt down, bolt down, bug out, bulge, bulge out, come out, crop up, dad, dada, daddy, domicile, down, drink down, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kill, kitchen, kitchen&homeappliances, menage, national, nursing home, pa, papa, pappa, place, plate, pop, pop music, pop out, pop up, pop-uptoasters, popping, popular, pour down, protrude, rest home, smallkitchenappliances, soda, soda pop, soda water, start, tonic, toss off
#
#  Categoria: officeproducts|officepaperproducts|paper|stationery|pens,pencils&writingsupplies|pens&refills|bottledink
# *** Sinônimos detectados (24):
# bottledink, compose, composition, fill again, indite, letter paper, newspaper, newspaper publisher, officepaperproducts, officeproducts, paper, pen, pencil, penitentiary, pens&refills, pens,pencils&writingsupplies, playpen, refill, replenish, report, stationery, theme, wallpaper, write
#
#  Categoria: computers&accessories|accessories&peripherals|cables&accessories|cables|ethernetcables
# *** Sinônimos detectados (37):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, cable, cable length, cable system, cable television, cable television service, cable's length, cablegram, cables, cables&accessories, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, ethernetcables, figurer, information processing system, line, overseas telegram, peripheral, peripheral device, reckoner, supplement, telegraph, transmission line, wire
#
#  Categoria: home&kitchen|craftmaterials|drawingmaterials|drawingmedia|pencils|woodenpencils
# *** Sinônimos detectados (28):
# abode, base, craftmaterials, domicile, drawingmaterials, drawingmedia, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, menage, national, nursing home, pencil, pencils, place, plate, rest home, woodenpencils
#
#  Categoria: electronics|cameras&photography|accessories|photostudio&lighting|photobackgroundaccessories|backgroundsupports
# *** Sinônimos detectados (38):
# accessary, accessories, accessory, accouterment, accoutrement, add-on, alight, appurtenance, backgroundsupports, camera, cameras&photography, dismount, electronics, fall, fire up, firing, get down, get off, ignite, ignition, illume, illuminate, illumine, inflammation, kindling, light, light up, lighting, perch, photobackgroundaccessories, photographic camera, photography, photostudio&lighting, picture taking, supplement, television camera, tv camera, unhorse
#
#  Categoria: officeproducts|officepaperproducts|paper|stationery|notebooks,writingpads&diaries|notepads&memobooks
# *** Sinônimos detectados (18):
# composition, diary, journal, letter paper, newspaper, newspaper publisher, notebook, notebook computer, notebooks,writingpads&diaries, notepad, notepads&memobooks, officepaperproducts, officeproducts, paper, report, stationery, theme, wallpaper
#
#  Categoria: officeproducts|officepaperproducts|paper|copy&printingpaper|colouredpaper
# *** Sinônimos detectados (18):
# colouredpaper, composition, copy, copy&printingpaper, imitate, newspaper, newspaper publisher, officepaperproducts, officeproducts, paper, re-create, replicate, report, simulate, theme, transcript, wallpaper, written matter
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|minifoodprocessors&choppers
# *** Sinônimos detectados (33):
# abode, base, chop, chopper, cleaver, domicile, dwelling, dwelling house, eggbeater, family, habitation, helicopter, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, meat cleaver, menage, minifoodprocessors&choppers, national, nursing home, pearly, place, plate, rest home, smallkitchenappliances, whirlybird
#
#  Categoria: electronics|hometheater,tv&video|avreceivers&amplifiers
# *** Sinônimos detectados (18):
# TV, amplifier, avreceivers&amplifiers, boob tube, electronics, goggle box, hometheater,tv&video, idiot box, picture, telecasting, television, television receiver, television set, telly, tv, tv set, video, video recording
#
#  Categoria: musicalinstruments|microphones|condenser
# *** Sinônimos detectados (9):
# capacitance, capacitor, condenser, electrical condenser, microphone, microphones, mike, musicalinstruments, optical condenser
#
#  Categoria: electronics|homeaudio|speakers|towerspeakers
# *** Sinônimos detectados (14):
# Speaker, electronics, homeaudio, loudspeaker, loudspeaker system, speaker, speaker system, speaker unit, speakers, talker, towerspeakers, utterer, verbaliser, verbalizer
#
#  Categoria: computers&accessories|tablets
# *** Sinônimos detectados (25):
# accessary, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, lozenge, pad, pad of paper, pill, reckoner, supplement, tab, tablet, tablets
#
#  Categoria: officeproducts|officepaperproducts|paper|stationery|notebooks,writingpads&diaries|compositionnotebooks
# *** Sinônimos detectados (17):
# composition, compositionnotebooks, diary, journal, letter paper, newspaper, newspaper publisher, notebook, notebook computer, notebooks,writingpads&diaries, officepaperproducts, officeproducts, paper, report, stationery, theme, wallpaper
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|kettles&hotwaterdispensers|electrickettles
# *** Sinônimos detectados (34):
# abode, base, boiler, domicile, dwelling, dwelling house, electrickettles, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kettle, kettle hole, kettledrum, kettleful, kettles&hotwaterdispensers, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, smallkitchenappliances, timpani, tympani, tympanum
#
#  Categoria: officeproducts|officeelectronics|calculators|scientific
# *** Sinônimos detectados (10):
# calculating machine, calculator, calculators, computer, estimator, figurer, officeelectronics, officeproducts, reckoner, scientific
#
#  Categoria: home&kitchen|heating,cooling&airquality|fans|tablefans
# *** Sinônimos detectados (52):
# abode, base, buff, chill, chilling, cool, cool down, cool off, cooling, cooling system, devotee, domicile, dwelling, dwelling house, family, fan, fans, fire up, habitation, heat, heat up, heating, heating plant, heating system, heating,cooling&airquality, home, home base, home plate, home&kitchen, hot up, house, household, ignite, inflame, interior, internal, kitchen, lover, menage, national, nursing home, place, plate, rest home, rooter, sports fan, stir up, tablefans, temperature reduction, wake, warming, winnow
#
#  Categoria: computers&accessories|accessories&peripherals|keyboards,mice&inputdevices|keyboard&mousesets
# *** Sinônimos detectados (29):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, black eye, calculator, computer, computer mouse, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, keyboard, keyboard&mousesets, keyboards,mice&inputdevices, mouse, peripheral, peripheral device, reckoner, shiner, supplement
#
#  Categoria: electronics|headphones,earbuds&accessories|headphones|on-ear
# *** Sinônimos detectados (22):
# accessary, accessory, accouterment, accoutrement, add-on, along, appurtenance, auricle, capitulum, ear, earphone, earpiece, electronics, headphone, headphones, headphones,earbuds&accessories, on, on-ear, phone, pinna, spike, supplement
#
#  Categoria: home&kitchen|homestorage&organization|laundryorganization|laundrybags
# *** Sinônimos detectados (36):
# abode, administration, arrangement, base, brass, constitution, domicile, dwelling, dwelling house, establishment, family, formation, governance, governing body, habitation, home, home base, home plate, home&kitchen, homestorage&organization, house, household, interior, internal, kitchen, laundrybags, laundryorganization, menage, national, nursing home, organisation, organization, place, plate, rest home, system
#
#  Categoria: computers&accessories|accessories&peripherals|laptopaccessories|lapdesks
# *** Sinônimos detectados (24):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, lapdesks, laptopaccessories, peripheral, peripheral device, reckoner, supplement
#
#  Categoria: computers&accessories|accessories&peripherals|uninterruptedpowersupplies
# *** Sinônimos detectados (23):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, peripheral, peripheral device, reckoner, supplement, uninterruptedpowersupplies
#
#  Categoria: home&kitchen|kitchen&homeappliances|coffee,tea&espresso|stovetopespressopots
# *** Sinônimos detectados (40):
# Camellia sinensis, abode, afternoon tea, base, burnt umber, chocolate, coffee, coffee bean, coffee berry, coffee tree, coffee,tea&espresso, deep brown, domicile, dwelling, dwelling house, espresso, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, java, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, stovetopespressopots, tea, tea leaf, teatime, umber
#
#  Categoria: home&kitchen|heating,cooling&airquality|waterheaters&geysers|instantwaterheaters
# *** Sinônimos detectados (46):
# abode, base, chill, chilling, cool, cool down, cool off, cooling, cooling system, domicile, dwelling, dwelling house, family, fire up, geyser, habitation, heat, heat up, heating, heating plant, heating system, heating,cooling&airquality, home, home base, home plate, home&kitchen, hot up, house, household, ignite, inflame, instantwaterheaters, interior, internal, kitchen, menage, national, nursing home, place, plate, rest home, stir up, temperature reduction, wake, warming, waterheaters&geysers
#
#  Categoria: home&kitchen|heating,cooling&airquality|roomheaters|electricheaters
# *** Sinônimos detectados (45):
# abode, base, chill, chilling, cool, cool down, cool off, cooling, cooling system, domicile, dwelling, dwelling house, electricheaters, family, fire up, habitation, heat, heat up, heating, heating plant, heating system, heating,cooling&airquality, home, home base, home plate, home&kitchen, hot up, house, household, ignite, inflame, interior, internal, kitchen, menage, national, nursing home, place, plate, rest home, roomheaters, stir up, temperature reduction, wake, warming
#
#  Categoria: computers&accessories|components|memory
# *** Sinônimos detectados (37):
# accessary, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, component, component part, components, computer, computer memory, computer storage, computers&accessories, computing device, computing machine, constituent, data processor, electronic computer, element, estimator, factor, figurer, information processing system, ingredient, memory, memory board, part, portion, reckoner, remembering, retention, retentiveness, retentivity, storage, store, supplement
#
#  Categoria: home&kitchen|kitchen&homeappliances|coffee,tea&espresso|coffeemakeraccessories|measuringspoons
# *** Sinônimos detectados (41):
# Camellia sinensis, abode, afternoon tea, base, burnt umber, chocolate, coffee, coffee bean, coffee berry, coffee tree, coffee,tea&espresso, coffeemakeraccessories, deep brown, domicile, dwelling, dwelling house, espresso, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, java, kitchen, kitchen&homeappliances, measuringspoons, menage, national, nursing home, place, plate, rest home, tea, tea leaf, teatime, umber
#
#  Categoria: home&kitchen|homestorage&organization|laundryorganization|laundrybaskets
# *** Sinônimos detectados (36):
# abode, administration, arrangement, base, brass, constitution, domicile, dwelling, dwelling house, establishment, family, formation, governance, governing body, habitation, home, home base, home plate, home&kitchen, homestorage&organization, house, household, interior, internal, kitchen, laundrybaskets, laundryorganization, menage, national, nursing home, organisation, organization, place, plate, rest home, system
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|digitalkitchenscales|digitalscales
# *** Sinônimos detectados (26):
# abode, base, digitalkitchenscales, digitalscales, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, smallkitchenappliances
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|vacuumsealers
# *** Sinônimos detectados (25):
# abode, base, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, smallkitchenappliances, vacuumsealers
#
#  Categoria: computers&accessories|accessories&peripherals|laptopaccessories|laptopchargers&powersupplies
# *** Sinônimos detectados (24):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, laptopaccessories, laptopchargers&powersupplies, peripheral, peripheral device, reckoner, supplement
#
#  Categoria: computers&accessories|accessories&peripherals|laptopaccessories|bags&sleeves|laptopsleeves&slipcases
# *** Sinônimos detectados (43):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, arm, bag, bagful, bags&sleeves, base, bulge, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, cup of tea, data processor, dish, electronic computer, estimator, figurer, grip, handbag, information processing system, laptopaccessories, laptopsleeves&slipcases, old bag, peripheral, peripheral device, pocket, pocketbook, purse, reckoner, sleeve, suitcase, supplement, traveling bag, travelling bag, udder
#
#  Categoria: electronics|accessories|memorycards|microsd
# *** Sinônimos detectados (11):
# accessary, accessories, accessory, accouterment, accoutrement, add-on, appurtenance, electronics, memorycards, microsd, supplement
#
#  Categoria: electronics|mobiles&accessories|mobileaccessories|photo&videoaccessories|tripods
# *** Sinônimos detectados (21):
# Mobile, Mobile River, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, electronics, exposure, mobile, mobileaccessories, mobiles&accessories, photo, photo&videoaccessories, photograph, pic, picture, supplement, tripod, tripods
#
#  Categoria: home&kitchen|kitchen&homeappliances|coffee,tea&espresso|dripcoffeemachines
# *** Sinônimos detectados (40):
# Camellia sinensis, abode, afternoon tea, base, burnt umber, chocolate, coffee, coffee bean, coffee berry, coffee tree, coffee,tea&espresso, deep brown, domicile, dripcoffeemachines, dwelling, dwelling house, espresso, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, java, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, tea, tea leaf, teatime, umber
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|oventoastergrills
# *** Sinônimos detectados (25):
# abode, base, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, menage, national, nursing home, oventoastergrills, place, plate, rest home, smallkitchenappliances
#
#  Categoria: electronics|mobiles&accessories|mobileaccessories|mounts|handlebarmounts
# *** Sinônimos detectados (34):
# Mobile, Mobile River, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, backing, bestride, climb, climb on, climb up, electronics, get on, go up, handlebarmounts, hop on, jump on, mobile, mobileaccessories, mobiles&accessories, mount, mount up, mountain, mounts, put on, ride, riding horse, rise, saddle horse, setting, supplement, wax
#
#  Categoria: home&kitchen|kitchen&homeappliances|vacuum,cleaning&ironing|vacuums&floorcare|vacuumaccessories|vacuumbags|handheldbags
# ...
#
#  Categoria: electronics|generalpurposebatteries&batterychargers|disposablebatteries
# *** Sinônimos detectados (3):
# disposablebatteries, electronics, generalpurposebatteries&batterychargers
#
#  Categoria: computers&accessories|accessories&peripherals|keyboards,mice&inputdevices|keyboard&miceaccessories|dustcovers
# *** Sinônimos detectados (30):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, black eye, calculator, computer, computer mouse, computer peripheral, computers&accessories, computing device, computing machine, data processor, dustcovers, electronic computer, estimator, figurer, information processing system, keyboard, keyboard&miceaccessories, keyboards,mice&inputdevices, mouse, peripheral, peripheral device, reckoner, shiner, supplement
#
#  Categoria: officeproducts|officepaperproducts|paper|stationery|pens,pencils&writingsupplies|pens&refills|retractableballpointpens
# *** Sinônimos detectados (24):
# compose, composition, fill again, indite, letter paper, newspaper, newspaper publisher, officepaperproducts, officeproducts, paper, pen, pencil, penitentiary, pens&refills, pens,pencils&writingsupplies, playpen, refill, replenish, report, retractableballpointpens, stationery, theme, wallpaper, write
#
#  Categoria: computers&accessories|accessories&peripherals|keyboards,mice&inputdevices|keyboard&miceaccessories|mousepads
# *** Sinônimos detectados (32):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, black eye, calculator, computer, computer mouse, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, keyboard, keyboard&miceaccessories, keyboards,mice&inputdevices, mouse, mouse mat, mousepad, mousepads, peripheral, peripheral device, reckoner, shiner, supplement
#
#  Categoria: electronics|headphones,earbuds&accessories|headphones|over-ear
# *** Sinônimos detectados (27):
# accessary, accessory, accouterment, accoutrement, add-on, all over, appurtenance, auricle, capitulum, complete, concluded, ear, earphone, earpiece, electronics, ended, headphone, headphones, headphones,earbuds&accessories, o'er, over, over-ear, phone, pinna, spike, supplement, terminated
#
#  Categoria: electronics|mobiles&accessories|mobileaccessories|photo&videoaccessories|flashes&selfielights|selfielights
# *** Sinônimos detectados (55):
# Mobile, Mobile River, New York minute, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, blink, blink of an eye, dart, dash, electronics, exposure, fanfare, flare, flash, flash bulb, flash lamp, flashbulb, flashes&selfielights, flashgun, flashing, flaunt, heartbeat, instant, jiffy, mobile, mobileaccessories, mobiles&accessories, news bulletin, newsbreak, newsflash, ostentate, ostentation, photo, photo&videoaccessories, photoflash, photograph, pic, picture, scoot, scud, selfielights, shoot, show off, split second, supplement, swank, trice, twinkle, twinkling, wink, winkle
#
#  Categoria: electronics|homeaudio|mediastreamingdevices|streamingclients
# *** Sinônimos detectados (4):
# electronics, homeaudio, mediastreamingdevices, streamingclients
#
#  Categoria: electronics|cameras&photography|accessories|cleaners|cleaningkits
# *** Sinônimos detectados (23):
# accessary, accessories, accessory, accouterment, accoutrement, add-on, appurtenance, camera, cameras&photography, cleaner, cleaners, cleaningkits, cleanser, cleansing agent, dry cleaner, dry cleaners, electronics, photographic camera, photography, picture taking, supplement, television camera, tv camera
#
#  Categoria: electronics|generalpurposebatteries&batterychargers|rechargeablebatteries
# *** Sinônimos detectados (3):
# electronics, generalpurposebatteries&batterychargers, rechargeablebatteries
#
#  Categoria: home&kitchen|kitchen&homeappliances|vacuum,cleaning&ironing|irons,steamers&accessories|irons|steamirons
# *** Sinônimos detectados (69):
# Fe, Mya arenaria, abode, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, atomic number 26, base, branding iron, chains, clean, clean house, cleaning, cleanse, cleansing, cleanup, domicile, dwelling, dwelling house, emptiness, family, habitation, home, home base, home plate, home&kitchen, hoover, house, houseclean, household, interior, internal, iron, iron out, ironing, irons, irons,steamers&accessories, kitchen, kitchen&homeappliances, long-neck clam, make clean, menage, national, nursing home, pick, place, plate, press, rest home, scavenge, smoothing iron, soft-shell clam, steam, steamer, steamer clam, steamirons, steamship, strip, supplement, vacancy, vacuity, vacuum, vacuum cleaner, vacuum,cleaning&ironing, vacuum-clean, void
#
#  Categoria: computers&accessories|networkingdevices|datacards&dongles
# *** Sinônimos detectados (21):
# accessary, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computers&accessories, computing device, computing machine, data processor, datacards&dongles, dongle, electronic computer, estimator, figurer, information processing system, networkingdevices, reckoner, supplement
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|kettles&hotwaterdispensers|kettle&toastersets
# *** Sinônimos detectados (34):
# abode, base, boiler, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kettle, kettle hole, kettle&toastersets, kettledrum, kettleful, kettles&hotwaterdispensers, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, smallkitchenappliances, timpani, tympani, tympanum
#
#  Categoria: electronics|mobiles&accessories|mobileaccessories|photo&videoaccessories|selfiesticks
# *** Sinônimos detectados (20):
# Mobile, Mobile River, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, electronics, exposure, mobile, mobileaccessories, mobiles&accessories, photo, photo&videoaccessories, photograph, pic, picture, selfiesticks, supplement
#
#  Categoria: computers&accessories|accessories&peripherals|laptopaccessories
# *** Sinônimos detectados (23):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, laptopaccessories, peripheral, peripheral device, reckoner, supplement
#
#  Categoria: computers&accessories|accessories&peripherals|cables&accessories|cables|usbcables
# *** Sinônimos detectados (37):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, cable, cable length, cable system, cable television, cable television service, cable's length, cablegram, cables, cables&accessories, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, line, overseas telegram, peripheral, peripheral device, reckoner, supplement, telegraph, transmission line, usbcables, wire
#
#  Categoria: computers&accessories|accessories&peripherals|tabletaccessories|screenprotectors
# *** Sinônimos detectados (24):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, information processing system, peripheral, peripheral device, reckoner, screenprotectors, supplement, tabletaccessories
#
#  Categoria: electronics|hometheater,tv&video|accessories|tvmounts,stands&turntables|tvwall&ceilingmounts
# *** Sinônimos detectados (57):
# TV, abide, accessary, accessories, accessory, accouterment, accoutrement, add-on, appurtenance, bandstand, base, bear, boob tube, brook, digest, electronics, endure, fend, goggle box, hometheater,tv&video, idiot box, lazy Susan, outdoor stage, pedestal, picture, place upright, point of view, put up, rack, remain firm, resist, sales booth, stall, stand, stand up, standpoint, standstill, stick out, stomach, suffer, supplement, support, telecasting, television, television receiver, television set, telly, tie-up, tolerate, turntable, tv, tv set, tvmounts,stands&turntables, tvwall&ceilingmounts, video, video recording, viewpoint
#
#  Categoria: computers&accessories|accessories&peripherals|harddiskbags
# *** Sinônimos detectados (23):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, harddiskbags, information processing system, peripheral, peripheral device, reckoner, supplement
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|sandwichmakers
# *** Sinônimos detectados (25):
# abode, base, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, sandwichmakers, smallkitchenappliances
#
#  Categoria: electronics|cameras&photography|accessories|tripods&monopods|tabletop&traveltripods
# *** Sinônimos detectados (20):
# accessary, accessories, accessory, accouterment, accoutrement, add-on, appurtenance, camera, cameras&photography, electronics, photographic camera, photography, picture taking, supplement, tabletop, tabletop&traveltripods, television camera, tripod, tripods&monopods, tv camera
#
#  Categoria: home&kitchen|heating,cooling&airquality|roomheaters
# *** Sinônimos detectados (44):
# abode, base, chill, chilling, cool, cool down, cool off, cooling, cooling system, domicile, dwelling, dwelling house, family, fire up, habitation, heat, heat up, heating, heating plant, heating system, heating,cooling&airquality, home, home base, home plate, home&kitchen, hot up, house, household, ignite, inflame, interior, internal, kitchen, menage, national, nursing home, place, plate, rest home, roomheaters, stir up, temperature reduction, wake, warming
#
#  Categoria: electronics|mobiles&accessories|mobileaccessories|styluspens
# *** Sinônimos detectados (14):
# Mobile, Mobile River, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, electronics, mobile, mobileaccessories, mobiles&accessories, styluspens, supplement
#
#  Categoria: electronics|cameras&photography|accessories|tripods&monopods|tripodlegs
# *** Sinônimos detectados (19):
# accessary, accessories, accessory, accouterment, accoutrement, add-on, appurtenance, camera, cameras&photography, electronics, photographic camera, photography, picture taking, supplement, television camera, tripod, tripodlegs, tripods&monopods, tv camera
#
#  Categoria: computers&accessories|networkingdevices|repeaters&extenders
# *** Sinônimos detectados (24):
# accessary, accessory, accouterment, accoutrement, add-on, appurtenance, calculator, computer, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, habitual criminal, information processing system, networkingdevices, recidivist, reckoner, repeater, repeaters&extenders, repeating firearm, supplement
#
#  Categoria: car&motorbike|caraccessories|interioraccessories|airpurifiers&ionizers
# *** Sinônimos detectados (19):
# airpurifiers&ionizers, auto, automobile, cable car, car, car&motorbike, caraccessories, cycle, elevator car, gondola, interioraccessories, machine, minibike, motorbike, motorcar, motorcycle, railcar, railroad car, railway car
#
#  Categoria: home&kitchen|heating,cooling&airquality|waterheaters&geysers|immersionrods
# *** Sinônimos detectados (46):
# abode, base, chill, chilling, cool, cool down, cool off, cooling, cooling system, domicile, dwelling, dwelling house, family, fire up, geyser, habitation, heat, heat up, heating, heating plant, heating system, heating,cooling&airquality, home, home base, home plate, home&kitchen, hot up, house, household, ignite, immersionrods, inflame, interior, internal, kitchen, menage, national, nursing home, place, plate, rest home, stir up, temperature reduction, wake, warming, waterheaters&geysers
#
#  Categoria: home&kitchen|kitchen&homeappliances|vacuum,cleaning&ironing|pressurewashers,steam&windowcleaners
# *** Sinônimos detectados (51):
# abode, base, clean, clean house, cleaning, cleanse, cleansing, cleanup, domicile, dwelling, dwelling house, emptiness, family, habitation, home, home base, home plate, home&kitchen, hoover, house, houseclean, household, interior, internal, iron, iron out, ironing, kitchen, kitchen&homeappliances, make clean, menage, national, nursing home, pick, place, plate, press, pressurewashers,steam&windowcleaners, rest home, scavenge, steam, steam clean, steamer, strip, vacancy, vacuity, vacuum, vacuum cleaner, vacuum,cleaning&ironing, vacuum-clean, void
#
#  Categoria: computers&accessories|accessories&peripherals|tabletaccessories|bags,cases&sleeves|cases
# *** Sinônimos detectados (75):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, arm, bag, bagful, bags,cases&sleeves, base, bulge, calculator, case, caseful, cases, casing, causa, cause, character, compositor's case, computer, computer peripheral, computers&accessories, computing device, computing machine, cup of tea, data processor, dish, display case, eccentric, electronic computer, encase, estimator, event, example, face, figurer, font, fount, grammatical case, grip, guinea pig, handbag, incase, information processing system, instance, lawsuit, old bag, peripheral, peripheral device, pillow slip, pillowcase, pocket, pocketbook, purse, reckoner, sheath, shell, showcase, sleeve, slip, subject, suit, suitcase, supplement, tabletaccessories, traveling bag, travelling bag, type, typeface, typesetter's case, udder, vitrine
#
#  Categoria: electronics|mobiles&accessories|mobileaccessories|mounts|bedstand&deskmounts
# *** Sinônimos detectados (34):
# Mobile, Mobile River, accessary, accessory, accouterment, accoutrement, add-on, appurtenance, backing, bedstand&deskmounts, bestride, climb, climb on, climb up, electronics, get on, go up, hop on, jump on, mobile, mobileaccessories, mobiles&accessories, mount, mount up, mountain, mounts, put on, ride, riding horse, rise, saddle horse, setting, supplement, wax
#
#  Categoria: home&kitchen|kitchen&homeappliances|smallkitchenappliances|digitalkitchenscales
# *** Sinônimos detectados (25):
# abode, base, digitalkitchenscales, domicile, dwelling, dwelling house, family, habitation, home, home base, home plate, home&kitchen, house, household, interior, internal, kitchen, kitchen&homeappliances, menage, national, nursing home, place, plate, rest home, smallkitchenappliances
#
#  Categoria: computers&accessories|accessories&peripherals|keyboards,mice&inputdevices|graphictablets
# *** Sinônimos detectados (29):
# accessary, accessories&peripherals, accessory, accouterment, accoutrement, add-on, appurtenance, black eye, calculator, computer, computer mouse, computer peripheral, computers&accessories, computing device, computing machine, data processor, electronic computer, estimator, figurer, graphictablets, information processing system, keyboard, keyboards,mice&inputdevices, mouse, peripheral, peripheral device, reckoner, shiner, supplement
#
#  Categoria: electronics|hometheater,tv&video|televisions|standardtelevisions
# *** Sinônimos detectados (19):
# TV, boob tube, electronics, goggle box, hometheater,tv&video, idiot box, picture, standardtelevisions, telecasting, television, television receiver, television set, television system, televisions, telly, tv, tv set, video, video recording

# %%
# Essa célula prepara o motor de busca que o sistema vai usar para encontrar produtos parecidos sem depender de palavras exatas.

# Gerar os embeddings para cada produto
embeddings = np.array([embedding_model.encode(str(text)) for text in df['product_name']])

# Certificar-se de que os embeddings estão no formato 2D (n, d)
embeddings = embeddings.reshape(len(df), -1)

# Criar o índice FAISS
index = faiss.IndexFlatL2(embeddings.shape[1])  # Usando uma indexação simples

# Adicionar os embeddings ao índice
index.add(embeddings.astype(np.float32))  # FAISS exige embeddings como float32

# Salvar o índice em um arquivo
faiss.write_index(index, "index")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import faiss
from sentence_transformers import SentenceTransformer
from transformers import T5Tokenizer, T5ForConditionalGeneration
from sklearn.preprocessing import MinMaxScaler
from matplotlib.patches import Patch
from math import pi

# Carregar modelos
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")
t5_model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")

# Função para buscar produtos no FAISS
def search_faiss(query, faiss_index, df, top_k=10):
    query_embedding = embedding_model.encode([query], normalize_embeddings=True)
    _, indices = faiss_index.search(query_embedding, top_k)
    return df.iloc[indices[0]].dropna()

# Função RAG

def generate_comparative_rag_text(df_metrics, tokenizer, t5_model):
    context = ""
    for _, row in df_metrics.iterrows():
        context += (
            f"Category: {row['Categoria']}, "
            f"Total Sales: {row['Total de Vendas']}, "
            f"Revenue: {row['Receita Estimada']:.2f}, "
            f"Average Ticket: {row['Ticket Médio']:.2f}, "
            f"Average Discount: {row['Desconto Médio (%)']:.2f}%, "
            f"Average Rating: {row['Avaliação Média']:.2f}. "
        )

    prompt = (
        "You are a data analyst. Based on the following product category sales data, "
        "perform a comparative analysis highlighting which category performs better in total sales, revenue, discount, and user rating. "
        "Then, provide actionable business insights:\n" + context
    )

    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=512)
    outputs = t5_model.generate(**inputs, max_length=250)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Função principal

def generate_charts_and_rag_text(resultados, df, faiss_index):
    categorias = list(resultados.keys())
    metrics = []

    total_sales_all = df["sales_quantity"].sum()
    print(f"Total geral de vendas (todos os produtos): {total_sales_all}")


    for category in categorias:
        sales = 0
        revenue = 0
        discounts = []
        ratings = []
        for product in resultados[category]:
            prod_data = df[df['product_id'] == product['product_id']]
            if not prod_data.empty:
                qty = prod_data["sales_quantity"].values[0]
                price = prod_data["discounted_price"].values[0]
                disc = prod_data["discount_percentage"].values[0]
                rate = prod_data["rating"].values[0]
                sales += qty
                revenue += qty * price
                discounts.append(disc)
                ratings.append(rate)

        ticket_medio = revenue / sales if sales else 0
        avg_discount = np.mean(discounts) if discounts else 0
        avg_rating = np.mean(ratings) if ratings else 0

        metrics.append({
            "Categoria": category,
            "Total de Vendas": sales,
            "Receita Estimada": revenue,
            "Ticket Médio": ticket_medio,
            "Desconto Médio (%)": avg_discount,
            "Avaliação Média": avg_rating
        })

    df_metrics = pd.DataFrame(metrics)

    total_sales_all = df["sales_quantity"].sum()

    # Gráfico de Pizza com 'Others'
    pie_labels = df_metrics["Categoria"].tolist()
    pie_values = df_metrics["Total de Vendas"].tolist()
    others = total_sales_all - sum(pie_values)
    if others > 0:
        pie_labels.append("Others")
        pie_values.append(others)

    cores_marcadores = ["tomato", "khaki", "MediumSeaGreen", "lightblue"][:len(pie_labels)]

    # Normalização para Radar (mantendo entre 50 e 80)
    scaler = MinMaxScaler(feature_range=(50, 80))
    cols_to_normalize = ['Total de Vendas', 'Receita Estimada', 'Ticket Médio', 'Desconto Médio (%)', 'Avaliação Média']
    values_scaled = scaler.fit_transform(df_metrics[cols_to_normalize])
    df_norm = pd.DataFrame(values_scaled, columns=cols_to_normalize)
    df_norm["Categoria"] = df_metrics["Categoria"]

    # Criar Subplots: Pizza + Radar
    fig = make_subplots(rows=1, cols=2, specs=[[{"type": "domain"}, {"type": "polar"}]])

    # Pizza
    fig.add_trace(go.Pie(
        labels=pie_labels,
        values=pie_values,
        marker_colors=cores_marcadores,
        hole=0.5,
        pull=[0.1 if label == "Others" else 0 for label in pie_labels],
        textposition="outside",
        textinfo="percent+label"
    ), row=1, col=1)

    # Radar
    for _, row in df_norm.iterrows():
        r = row[cols_to_normalize].tolist()
        fig.add_trace(go.Scatterpolar(
            r=r + [r[0]],
            theta=cols_to_normalize + [cols_to_normalize[0]],
            fill='toself',
            name=row["Categoria"]
        ), row=1, col=2)

    # Layout Final
    fig.update_layout(
        title="Análise Comparativa por Categoria",
        annotations=[dict(text="Vendas", x=0.17, y=0.5, font_size=18, showarrow=False)],
        polar=dict(
            radialaxis=dict(
                visible=True,
                range=[20, 100],
                showticklabels=True,
                tickfont_size=10
            )
        ),
        legend_title_text="Categorias",
        legend=dict(orientation="h", xanchor="center", x=0.5),
        showlegend=True
    )

    fig.show()

    # Mostrar valores reais usados no radar
    print("\n--- Valores reais usados no gráfico Radar ---")
    print(df_metrics)

    # Gera texto com IA
    generated_text = generate_comparative_rag_text(df_metrics, tokenizer, t5_model)
    print("\n- Insights (com RAG):\n")
    print(generated_text)

# Carregar dados e índice
df = pd.read_csv("amazon_with_sales.csv")
faiss_index = faiss.read_index("index")

generate_charts_and_rag_text(resultados, df, faiss_index)
# Out:
# Total geral de vendas (todos os produtos): 148967
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="63007d44-62a2-4f5f-964f-21d746079b14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63007d44-62a2-4f5f-964f-21d746079b14")) {                    Plotly.newPlot(                        "63007d44-62a2-4f5f-964f-21d746079b14",                        [{"hole":0.5,"labels":["Phone","Tv","Others"],"marker":{"colors":["tomato","khaki","MediumSeaGreen"]},"pull":[0,0,0.1],"textinfo":"percent+label","textposition":"outside","values":[11767,10699,126501],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.0,1.0]}},{"fill":"toself","name":"Phone","r":[80.0,50.0,50.0,80.0,50.0,80.0],"theta":["Total de Vendas","Receita Estimada","Ticket Médio","Desconto Médio (%)","Avaliação Média","Total de Vendas"],"type":"scatterpolar","subplot":"polar"},{"fill":"toself","name":"Tv","r":[50.0,80.0,80.0,50.0,80.0,50.0],"theta":["Total de Vendas","Receita Estimada","Ticket Médio","Desconto Médio (%)","Avaliação Média","Total de Vendas"],"type":"scatterpolar","subplot":"polar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpol ...
# --- Valores reais usados no gráfico Radar ---
#   Categoria  Total de Vendas  Receita Estimada  Ticket Médio  \
# 0     Phone            11767        11576629.0    983.821620
# 1        Tv            10699        18587075.0   1737.272175
#
#    Desconto Médio (%)  Avaliação Média
# 0               63.74            3.898
# 1               51.42            4.196
#
# - Insights (com RAG):
#
# Total sales for the phone category were 11767, revenue was 11576629.00, and average Ticket sales were 983.82, with a average discount of 63.74%. The average rating for the phone category was 4.20.

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from sentence_transformers import SentenceTransformer
from transformers import T5Tokenizer, T5ForConditionalGeneration
from sklearn.preprocessing import MinMaxScaler

# Carregar modelos
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")
t5_model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")

# Função para gerar texto RAG comparativo por período
def generate_comparative_rag_text_period(df_metrics, total_category_sales, tokenizer, t5_model):
    context = ""
    for _, row in df_metrics.iterrows():
        context += (
            f"Period: {row['Período']}, "
            f"Sales in Period: {row['Total de Vendas']}, "
            f"Share of Total: {row['% no Total da Categoria']:.2f}%, "
            f"Revenue: {row['Receita Estimada']:.2f}, "
            f"Avg Ticket: {row['Ticket Médio']:.2f}, "
            f"Avg Discount: {row['Desconto Médio (%)']:.2f}%, "
            f"Avg Rating: {row['Avaliação Média']:.2f}. "
        )

    prompt = (
        "You are a senior sales analyst. Given the sales data below, compare the periodos in terms of total sales, revenue, discount, and rating."
        "perform a comparative analysis highlighting which category performs better in total sales, revenue, discount, and user rating."
        "Then, provide actionable business insights:\n" + context
    )

    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=512)
    outputs = t5_model.generate(**inputs, max_length=400)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Função principal
def generate_charts_and_rag_text(resultados, df, category_total_sales):
    period_list = list(resultados[list(resultados.keys())[0]].keys())
    category_name = list(resultados.keys())[0]
    total_sales = category_total_sales.get(category_name, 0)

    metrics = []
    for period in period_list:
        sales = 0
        revenue = 0
        discounts = []
        ratings = []

        for product in resultados[category_name][period]:
            product_id = str(product['product_id']).strip()
            product_info = df[df['product_id'].astype(str).str.strip() == product_id]

            if product_info.empty:
                continue

            qty = pd.to_numeric(product_info["sales_quantity"].values[0], errors='coerce')
            price = pd.to_numeric(product_info["discounted_price"].values[0], errors='coerce')
            disc = pd.to_numeric(product_info["discount_percentage"].values[0], errors='coerce')
            rate = pd.to_numeric(product_info["rating"].values[0], errors='coerce')

            if pd.isna(qty) or pd.isna(price):
                continue

            sales += qty
            revenue += qty * price
            discounts.append(disc)
            ratings.append(rate)

        ticket_medio = revenue / sales if sales else 0
        avg_discount = np.mean(discounts) if discounts else 0
        avg_rating = np.mean(ratings) if ratings else 0
        pct_total = (sales / total_sales * 100) if total_sales else 0

        metrics.append({
            "Período": period,
            "Total de Vendas": sales,
            "Receita Estimada": revenue,
            "Ticket Médio": ticket_medio,
            "Desconto Médio (%)": avg_discount,
            "Avaliação Média": avg_rating,
            "% no Total da Categoria": pct_total
        })

    df_metrics = pd.DataFrame(metrics)

    # Gráfico de Pizza
    pie_labels = df_metrics["Período"].tolist()
    pie_values = df_metrics["% no Total da Categoria"].tolist()
    outros_pct = 100 - sum(pie_values)
    if outros_pct > 0.5:
        pie_labels.append("Others")
        pie_values.append(outros_pct)

    cores_marcadores = ["tomato", "khaki", "MediumSeaGreen"][:len(pie_labels)]

    # Normalização para Radar
    scaler = MinMaxScaler(feature_range=(50, 80))
    cols_to_normalize = ['Total de Vendas', 'Receita Estimada', 'Ticket Médio', 'Desconto Médio (%)', 'Avaliação Média']
    values_scaled = scaler.fit_transform(df_metrics[cols_to_normalize])
    df_norm = pd.DataFrame(values_scaled, columns=cols_to_normalize)
    df_norm["Período"] = df_metrics["Período"].fillna("Indefinido")

    # Subplots com Pizza e Radar
    fig = make_subplots(rows=1, cols=2, specs=[[{"type": "domain"}, {"type": "polar"}]])

    fig.add_trace(go.Pie(
        labels=pie_labels,
        values=pie_values,
        marker_colors=cores_marcadores,
        hole=0.5,
        pull=[0.1 if label == "Others" else 0 for label in pie_labels],
        textposition="outside",
        textinfo="percent+label"
    ), row=1, col=1)

    for _, row in df_norm.iterrows():
        r = row[cols_to_normalize].tolist()
        fig.add_trace(go.Scatterpolar(
            r=r + [r[0]],
            theta=cols_to_normalize + [cols_to_normalize[0]],
            fill='toself',
            name=row["Período"]
        ), row=1, col=2)

    fig.update_layout(
        title=f"Análise por Período - Categoria '{category_name}'",
        annotations=[dict(text="Vendas", x=0.17, y=0.5, font_size=18, showarrow=False)],
        polar=dict(
            radialaxis=dict(
                visible=True,
                range=[20, 100],
                showticklabels=True,
                tickfont_size=10
            )
        ),
        legend_title_text="Períodos",
        legend=dict(orientation="h", xanchor="center", x=0.5),
        showlegend=True
    )

    fig.show()

    # Mostrar valores reais usados no radar
    print("\n--- Valores reais usados no gráfico Radar ---")
    print(df_metrics)

    # RAG
    generated_text = generate_comparative_rag_text_period(df_metrics, total_sales, tokenizer, t5_model)
    print("\n- Insights (com RAG):\n")
    print(generated_text)

generate_charts_and_rag_text(period_resultados, df, category_total_sales)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2ea9a35d-733b-43b1-b9a3-4e5d0f24acdc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ea9a35d-733b-43b1-b9a3-4e5d0f24acdc")) {                    Plotly.newPlot(                        "2ea9a35d-733b-43b1-b9a3-4e5d0f24acdc",                        [{"hole":0.5,"labels":["Spring","Winter","Others"],"marker":{"colors":["tomato","khaki","MediumSeaGreen"]},"pull":[0,0,0.1],"textinfo":"percent+label","textposition":"outside","values":[24.615857406269207,13.675476336816224,61.70866625691457],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.0,1.0]}},{"fill":"toself","name":"Spring","r":[80.0,80.0,50.0,80.0,50.0,80.0],"theta":["Total de Vendas","Receita Estimada","Ticket Médio","Desconto Médio (%)","Avaliação Média","Total de Vendas"],"type":"scatterpolar","subplot":"polar"},{"fill":"toself","name":"Winter","r":[50.0,50.0,80.0,50.0,80.0,50.0],"theta":["Total de Vendas","Receita Estimada","Ticket Médio","Desconto Médio (%)","Avaliação Média","Total de Vendas"],"type":"scatterpolar","subplot":"polar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"tick ...
# --- Valores reais usados no gráfico Radar ---
#   Período  Total de Vendas  Receita Estimada  Ticket Médio  \
# 0  Spring             1602         2482456.0   1549.598002
# 1  Winter              890         1531701.0   1721.012360
#
#    Desconto Médio (%)  Avaliação Média  % no Total da Categoria
# 0           67.272727         4.054545                24.615857
# 1           64.923077         4.123077                13.675476
#
# - Insights (com RAG):
#
# Total sales in the period: 1602, Share of Total: 24.62%, Revenue: 2482456.00, Avg Ticket: 1549.60, Avg Discount: 67.27%, Avg Rating: 4.12.
